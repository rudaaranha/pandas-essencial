# %% [markdown]
# ## **Pandas Essencial**
# **Prof. Dr. Samuel Martins (@hisamuka @xavecoding)** <br/>
# xavecoding: https://youtube.com/c/xavecoding <br/>
#
# Neste tutorial, vamos aprender o essencial da biblioteca _Pandas_ para manipulação de dados.<br/><br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# ### Pacotes usados neste Notebook

# %%
# pacotes usados neste notebook
import pandas as pd

# %% [markdown]
# <h1>Manipulação de Dados com Pandas</h1><hr/>

# %% [markdown]
# <h2>1. Manipulação Básica de Datasets</h2>
# <hr/>

# %% [markdown]
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil <br/>
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019**. <br/>
# Cada *amostra (registro/linha)* consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil. <br/>
# Alguns dos principais *atributos* (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.
#
#
# \* O arquivo disponibilizado no Kaggle está no formato *tsv*. Embora o _pandas_ consiga abrí-lo normalmente, convertemos tal arquivo para o formato *CSV*, que é um dos formatos mais utilizados, e mudamos seu separado para ';' apenas para mostrar algumas opções da função de carregamento.

# %% [markdown]
# ### 1.1. Importando o Dataset
# Para carregar um dataset no formato csv, basta utilizar a função `read_csv` do pandas. Por padrão, ela considera _','_ como separador.

# %%
data = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019.csv')

# %%
data
# Out:
#        Unnamed: 0;DATA INICIAL;DATA FINAL;REGIÃO;ESTADO;PRODUTO;NÚMERO DE POSTOS PESQUISADOS;UNIDADE DE MEDIDA;PREÇO MÉDIO REVENDA;DESVIO PADRÃO REVENDA;PREÇO MÍNIMO REVENDA;PREÇO MÁXIMO REVENDA;MARGEM MÉDIA REVENDA;COEF DE VARIAÇÃO REVENDA;PREÇO MÉDIO DISTRIBUIÇÃO;DESVIO PADRÃO DISTRIBUIÇÃO;PREÇO MÍNIMO DISTRIBUIÇÃO;PREÇO MÁXIMO DISTRIBUIÇÃO;COEF DE VARIAÇÃO DISTRIBUIÇÃO;MÊS;ANO
# 0       0;2004-05-09;2004-05-15;CENTRO OESTE;DISTRITO ...
# 1       1;2004-05-09;2004-05-15;CENTRO OESTE;GOIAS;ETA...
# 2       2;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 3       3;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 4       4;2004-05-09;2004-05-15;NORDESTE;ALAGOAS;ETANO...
# ...                                                   ...
# 106818  106818;2019-06-23;2019-06-29;NORDESTE;RIO GRAN...
# 106819  106819;2019-06-23;2019-06-29;SUL;RIO GRANDE DO...
# 106820  106820;2019-06-23;2019-06-29;SUL;SANTA CATARIN...
# 106821  106821;2019-06-23;2019-06-29;SUDESTE;SAO PAULO...
# 106822  106822;2019-06-23;2019-06-29;NORDESTE;SERGIPE;...
#
# [106823 rows x 1 columns]

# %% [markdown]
# O dataset não foi carregado corretamente pois o separador utilizado seu arquivo CSV era ';' e não a ','. <br/>
# Vamos então carregá-lo corretamente:

# %%
# Carregando o dataset corretamente ==> neste caso, usa o separador ';'
data = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019.csv', sep=';')

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# ### 1.2. Exibindo as primeiras linhas do Dataset
# A função `.head()` exibe as 5 primeiras linhas do dataset/tabela/Data Frame.

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
# Exibindo as 10 primeiras linhas do dataframe
data.head(10)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7           7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8           8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
# 5                1.383                  0.132  ...                 2.050
# 6                1.453                  0.218  ...                 1.950
# 7                1.631                  0.158  ...                 2.000
# 8                1.284                  0.130  ...                 1.699
# 9                1.224                  0.141  ...                 1.700
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
# 5                 0.426                    0.095                     0.957
# 6                 0.353                    0.150                       1.1
# 7                 0.515                    0.097                     1.116
# 8                 0.353                    0.101                     0.931
# 9                 0.277                    0.115                     0.947
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
# 5                      0.128                    0.5686
# 6                      0.068                    0.7332
# 7                      0.091                    0.9923
# 8                      0.072                    0.7577
# 9                      0.091                    0.5643
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
# 5                      1.35                         0.134   5  2004
# 6                     1.294                         0.062   5  2004
# 7                   1.36183                         0.082   5  2004
# 8                    1.2972                         0.077   5  2004
# 9                    1.3541                         0.096   5  2004
#
# [10 rows x 21 columns]

# %% [markdown]
# ### 1.3 Informações do Dataset e Elementos Chave

# %% [markdown]
# ### 1.3.1 Informações gerais sobre o Dataset

# %%
# Traz informações importantes sobre o dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  12  MARGEM MÉDIA REVENDA           106823 non-null  object
#  13  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  19  MÊS                            106823 non-null  int64
#  20  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(4), object(12)
# memory usage: 17.1+ MB

# %% [markdown]
# A primeira coluna da tabela, chamada _'Unnamed: 0'_, parece não significar nada. Na verdade, ela parece ser os **índices** da tabela, que foram salvos como uma _coluna_.<br/>
# Veremos jajá como **remover tal coluna**.
#
# Outro ponto é que, aparentemente, nenhum atributo/coluna possui valores nulos (_null_), uma vez que o número de registros do dataframe e os números de valores _non-null_ é de **106823**. <br/>
# Mas, veremos que não é bem assim para esse caso.
#
# Além disso, note que alguns atributos/colunas, p. ex., 'PREÇO MÉDIO DISTRIBUIÇÃO', possui tipo de dado `object` ao inves de `float`. Esse `object`, no geral, representa strings. Isso parece estranho e suspeito. Veremos se isso é problemático mais para frente.

# %% [markdown]
# ### 1.3.2 Data Frame
# Todo dataset carregado (dados estruturados) é um `Data Frame`: 'Tabela' bi-dimensional, de tamanho mutável, com dados potencialmente heterogêneos. <br/>

# %%
# O type vai retornar o tipo dataframe
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Podemos acessar as **dimensões do Data Frame** (número de linhas x número de colunas) utilizando o atributo `.shape` do Data Frame.

# %%
data.shape
# Out:
# (106823, 21)

# %%
print(f'O DataFrame possui {data.shape[0]} linhas (observações/registros) e {data.shape[1]} colunas (atributos/variáveis).')
# Out:
# O DataFrame possui 106823 linhas (observações/registros) e 21 colunas (atributos/variáveis).

# %% [markdown]
# #### **Criando um DataFrame**
#
# Podemos criar um DataFrame a partir de um _dicionário_, onde cada **chave** possui uma **lista de elementos de igual tamanho**.<br/>
# As **chaves** representam as **colunas** e **cada um dos valores de sua lista** representa o **valor da linha** correspondente para aquela coluna.

# %%
personagens_df = pd.DataFrame({
    'nome': ['Luke Skywalker', 'Yoda', 'Palpatine'],
    'idade': [16, 1000, 70],
    'peso': [70, 15.5, 60.2],
    'eh jedi': [True, True, False]  # o nome das colunas podem ter espaços
})

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16  70.0     True
# 1            Yoda   1000  15.5     True
# 2       Palpatine     70  60.2    False

# %%
personagens_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      object
#  1   idade    3 non-null      int64
#  2   peso     3 non-null      float64
#  3   eh jedi  3 non-null      bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 207.0+ bytes

# %% [markdown]
# #### **VEJA MAIS**
# Criando um Data Frame a partir de um dicionário: https://www.geeksforgeeks.org/how-to-create-dataframe-from-dictionary-in-python-pandas/

# %% [markdown]
# #### **Renomeando as colunas de um DataFrame**
# **===>** O atributo `DataFrame.columns` retorna uma "lista" com os **nomes de todas as colunas** do data frame.

# %%
personagens_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'eh jedi'], dtype='object')

# %%
# o .columns retorna um tipo Index, que é um tipo do pandas
type(personagens_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
# É possível converter o tipo Index para uma lista do python
list(personagens_df.columns)
# Out:
# ['nome', 'idade', 'peso', 'eh jedi']

# %% [markdown]
# <br/>
#
# **===>** Para **renomear colunas** do data frame, utilize o método `DataFrame.rename`, que retorna uma _cópia_ do data frame com as as colunas renomeadas:

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16  70.0     True
# 1            Yoda   1000  15.5     True
# 2       Palpatine     70  60.2    False

# %%
personagens_df_renomeado = personagens_df.rename(columns={
    'nome': 'Nome', # Renomeia a coluna 'nome' para 'Nome' (com N maiúsculo)
    'idade': 'Idade' # Renomeia a coluna 'idade' para 'Idade' (com I maiúsculo)
})

# %%
personagens_df_renomeado
# Out:
#              Nome  Idade  peso  eh jedi
# 0  Luke Skywalker     16  70.0     True
# 1            Yoda   1000  15.5     True
# 2       Palpatine     70  60.2    False

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16  70.0     True
# 1            Yoda   1000  15.5     True
# 2       Palpatine     70  60.2    False

# %% [markdown]
# Para renomear o _próprio_ data frame em questão, utilize o parâmetro `inplace=True`:

# %%
personagens_df.rename(columns={
    'nome': 'Nome', # Renomeia a coluna 'nome' para 'Nome' (com N maiúsculo)
    'idade': 'Idade', # Renomeia a coluna 'idade' para 'Idade' (com I maiúsculo)
    'eh jedi': 'Jedi?'}, 
    inplace=True
)

# %%
personagens_df
# Out:
#              Nome  Idade  peso  Jedi?
# 0  Luke Skywalker     16  70.0   True
# 1            Yoda   1000  15.5   True
# 2       Palpatine     70  60.2  False

# %% [markdown]
# <br/>
#
# **===>** Uma outra forma de **renomear todas as colunas** de um data frame é passar uma _lista_ com os novos nomes das colunas para o atributo `DataFrame.columns`:

# %%
personagens_df.columns
# Out:
# Index(['Nome', 'Idade', 'peso', 'Jedi?'], dtype='object')

# %%
# Vamos deixar todas as colunas com nomes maiúsculos
personagens_df.columns = ['NOME', 'IDADE', 'PESO', 'JEDI?']

# %%
personagens_df
# Out:
#              NOME  IDADE  PESO  JEDI?
# 0  Luke Skywalker     16  70.0   True
# 1            Yoda   1000  15.5   True
# 2       Palpatine     70  60.2  False

# %% [markdown]
# ### 1.3.3 Series

# %% [markdown]
# Array uni-dimensional com os dados e rótulos de um eixo.

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
# Selecionando uma coluna inteira
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
# Outra forma de selecionar uma coluna inteira
# Esta forma só funciona para colunas com nomes sem espaços, acentos, etc. (caracteres inválidos)
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
# Tipo: series
type(data['ESTADO'])
# Out:
# pandas.core.series.Series

# %%
# Selecionando a observação indexada no índice [1] do dataframe (dados armazenados na linha 1)
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Name: 1, dtype: object

# %%
# Tipo: series
type(data.iloc[1])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### **Criando uma Series**
#
# Podemos criar um DataFrame a partir de uma lista de elementos.

# %%
pd.Series([5.5, 6.0, 9.5])
# Out:
# 0    5.5
# 1    6.0
# 2    9.5
# dtype: float64

# %% [markdown]
# Podemos alterar o **nome dos índices** (veremos melhor jajá) e o **nome da Series** (o que ela representa):

# %%
pd.Series([5.5, 6.0, 9.5], index=['prova 1', 'prova 2', 'projeto'], name='Notas do Luke Skywalker')
# Out:
# prova 1    5.5
# prova 2    6.0
# projeto    9.5
# Name: Notas do Luke Skywalker, dtype: float64

# %% [markdown]
# #### **VEJA MAIS**
# https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html

# %% [markdown]
# ### 1.3.4 Atribuindo Dados

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.1 Atribuindo constantes

# %%
produto_view = data['PRODUTO']  # A series retornada referente à coluna, NÃO É UMA CÓPIA, mas sim, uma REFERÊNCIA
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_copy_backup = data['PRODUTO'].copy() # Retorna uma cópia da coluna 'PRODUTO'
produto_copy_backup
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
data['PRODUTO'] = 'Combustível' # Atribuindo o valor constante 'COMBUSTÍVEL'para linha do dataframe na coluna 'PRODUTO'

# %%
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_copy_backup # Esse vai manter os valores originais, até que seja atualizado
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %% [markdown]
# #### 1.3.4.2 Atribuindo listas ou series

# %%
nrows, ncols = data.shape
nrows, ncols
# Out:
# (106823, 21)

# %%
novos_produtos = [f'Produto {i}' for i in range(nrows)]
len(novos_produtos)
# Out:
# 106823

# %%
# A quantidade de elementos da lista 'novos_produtos' é igual ao número de linhas do dataframe
data['PRODUTO'] = novos_produtos

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO         PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL       Produto 0                           127
# 1                     GOIAS       Produto 1                           387
# 2               MATO GROSSO       Produto 2                           192
# 3        MATO GROSSO DO SUL       Produto 3                           162
# 4                   ALAGOAS       Produto 4                           103
# ...                     ...             ...                           ...
# 106818  RIO GRANDE DO NORTE  Produto 106818                             7
# 106819    RIO GRANDE DO SUL  Produto 106819                            23
# 106820       SANTA CATARINA  Produto 106820                            24
# 106821            SAO PAULO  Produto 106821                            52
# 106822              SERGIPE  Produto 106822                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %%
print(produto_view)
print('\n')
print(produto_copy_backup)
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object
#
#
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
# Voltando para os dados originais
data['PRODUTO'] = produto_copy_backup # produto_copy_backup é uma Series

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.3 Criando novas colunas
# Para **criar uma nova coluna** em um data frame, basta atribuirmos uma _lista/Series de valores_ ou uma _constante_ a uma **nova 'chave'** do data frame. <br/>
#
# **PS:** A _quantidade de valores_ da lista precisa ser **igual** ao _número de linhas/registros_ do data frame.

# %%
# Criando uma coluna a partir de um valor constante/default 
# Todas as linhas terão o mesmo valor para essa nova coluna
data['coluna sem nocao'] = 'DEFAULT'
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 0                1.288                  0.016  ...                 0.463
# 1                1.162                  0.114  ...                 0.399
# 2                1.389                  0.097  ...                 0.419
# 3                1.262                  0.070  ...                 0.432
# 4                1.181                  0.078  ...                  0.24
#
#    COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                     0.012                    0.825
# 1                     0.098                    0.763
# 2                     0.070                     0.97
# 3                     0.055                     0.83
# 4                     0.066                    0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
#    coluna sem nocao
# 0           DEFAULT
# 1           DEFAULT
# 2           DEFAULT
# 3           DEFAULT
# 4           DEFAULT
#
# [5 rows x 22 columns]

# %%
# Criando uma coluna a partir de uma lista
data['coluna a partir de lista'] = range(data.shape[0])
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# 0                1.288                  0.016  ...                     0.012
# 1                1.162                  0.114  ...                     0.098
# 2                1.389                  0.097  ...                     0.070
# 3                1.262                  0.070  ...                     0.055
# 4                1.181                  0.078  ...                     0.066
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                         0.133   5  2004          DEFAULT
# 1                         0.115   5  2004          DEFAULT
# 2                         0.098   5  2004          DEFAULT
# 3                         0.143   5  2004          DEFAULT
# 4                         0.082   5  2004          DEFAULT
#
#    coluna a partir de lista
# 0                         0
# 1                         1
# 2                         2
# 3                         3
# 4                         4
#
# [5 rows x 23 columns]

# %%
# Nesse caso, não funciona porque a quantidade de elementos da lista (a serem atribuídos à nova coluna) é 
# diferente da quantidade de linhas do dataframe
#data['nao funciona'] = [1, 2, 3]

# %% [markdown]
# <br/>
#
# Outro exemplo:

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# 0                1.288                  0.016  ...                     0.012
# 1                1.162                  0.114  ...                     0.098
# 2                1.389                  0.097  ...                     0.070
# 3                1.262                  0.070  ...                     0.055
# 4                1.181                  0.078  ...                     0.066
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                         0.133   5  2004          DEFAULT
# 1                         0.115   5  2004          DEFAULT
# 2                         0.098   5  2004          DEFAULT
# 3                         0.143   5  2004          DEFAULT
# 4                         0.082   5  2004          DEFAULT
#
#    coluna a partir de lista
# 0                         0
# 1                         1
# 2                         2
# 3                         3
# 4                         4
#
# [5 rows x 23 columns]

# %%
data['PREÇO MÉDIO REVENDA (dólares)'] = data['PREÇO MÉDIO REVENDA'] * 6.0

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                        0.11
# 1                          0.763                       0.088
# 2                           0.97                       0.095
# 3                           0.83                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                           0
# 106819                     2.451                       0.402
# 106820                     1.998                           0
# 106821                     2.374                       0.165
# 106822                     2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                     0.9666
# 1                         0.5013                       1.05
# 2                         0.5614                      1.161
# 3                         0.5991                    1.22242
# 4                         0.7441                     1.0317
# ...                          ...                        ...
# 106818                     2.756                      2.756
# 106819                    1.9842                     2.8661
# 106820                    1.9981                     1.9981
# 106821                    2.0179                     2.5093
# 106822                    2.5175                     2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                              0.133   5  2004          DEFAULT
# 1                              0.115   5  2004          DEFAULT
# 2                              0.098   5  2004          DEFAULT
# 3                              0.143   5  2004          DEFAULT
# 4                              0.082   5  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106818                             0   6  2019          DEFAULT
# 106819                         0.164   6  2019          DEFAULT
# 106820                             0   6  2019          DEFAULT
# 106821                          0.07   6  2019          DEFAULT
# 106822                             0   6  2019          DEFAULT
#
#        coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                             0                          7.728
# 1                             1                          6.972
# 2                             2                          8.334
# 3                             3                          7.572
# 4                             4                          7.086
# ...                         ...                            ...
# 106818                   106818                         21.444
# 106819                   106819                         20.406
# 106820                   106820                         17.472
# 106821                   106821                         18.120
# 106822                   106822                         22.182
#
# [106823 rows x 24 columns]

# %% [markdown]
# **PS:** Obviamente, a lógica correta em converter o preço dos combustíveis em reais para dólares não é considerar uma taxa de câmbio fixa, uma vez que cada preço em Real foi aferido em um momento diferente.

# %% [markdown]
# ### 1.3.4 Índices

# %% [markdown]
# Todo Data Frame possui **índices**, que não são considerado colunas da tabela. Tais índices são comumente **númericos**, de 0 a num_linhas-1, mas também podem ser **textuais (rótulos/labels)**.

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                        0.11
# 1                          0.763                       0.088
# 2                           0.97                       0.095
# 3                           0.83                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                           0
# 106819                     2.451                       0.402
# 106820                     1.998                           0
# 106821                     2.374                       0.165
# 106822                     2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                     0.9666
# 1                         0.5013                       1.05
# 2                         0.5614                      1.161
# 3                         0.5991                    1.22242
# 4                         0.7441                     1.0317
# ...                          ...                        ...
# 106818                     2.756                      2.756
# 106819                    1.9842                     2.8661
# 106820                    1.9981                     1.9981
# 106821                    2.0179                     2.5093
# 106822                    2.5175                     2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                              0.133   5  2004          DEFAULT
# 1                              0.115   5  2004          DEFAULT
# 2                              0.098   5  2004          DEFAULT
# 3                              0.143   5  2004          DEFAULT
# 4                              0.082   5  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106818                             0   6  2019          DEFAULT
# 106819                         0.164   6  2019          DEFAULT
# 106820                             0   6  2019          DEFAULT
# 106821                          0.07   6  2019          DEFAULT
# 106822                             0   6  2019          DEFAULT
#
#        coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                             0                          7.728
# 1                             1                          6.972
# 2                             2                          8.334
# 3                             3                          7.572
# 4                             4                          7.086
# ...                         ...                            ...
# 106818                   106818                         21.444
# 106819                   106819                         20.406
# 106820                   106820                         17.472
# 106821                   106821                         18.120
# 106822                   106822                         22.182
#
# [106823 rows x 24 columns]

# %%
# O Método para acessar os índices é o atributo .index
data.index
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %% [markdown]
# Use `list(data.index)` ou `data.index.to_list()` para converter um RangeIndex para uma python list.

# %% [markdown]
# #### **Exemplo de Data Frame com Índices Textuais (labels)**

# %%
# Os nomes dos índeces são os próprios produtos e não numéricos (considerando que cada produto é único no dataframe)

pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=['XboxOne', 'Playstation4', 'Switch'])

# %%
pesquisa_de_satisfacao.head()
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.index
# Out:
# Index(['XboxOne', 'Playstation4', 'Switch'], dtype='object')

# %% [markdown]
# ### 1.4 Selecionando uma ou mais amostras ou observações (Indexação)

# %% [markdown]
# #### **==>  Index-based selection (seleção baseada em Índices)**
# Mostrando linhas específicas de um DataFrame:
#
# `iloc`: seleciona elementos do Dataframe, baseado em seu **índice (número)** --> row-first, column-second

# %% [markdown]
# **Selecionando uma amostra(observação)/linha:**

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   coluna sem nocao coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0          DEFAULT                        0                          7.728
# 1          DEFAULT                        1                          6.972
# 2          DEFAULT                        2                          8.334
# 3          DEFAULT                        3                          7.572
# 4          DEFAULT                        4                          7.086
#
# [5 rows x 24 columns]

# %%
# Visualizando a linha 1 ===> observação (amostra) de índice [1] do dataframe
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# coluna sem nocao                          DEFAULT
# coluna a partir de lista                        1
# PREÇO MÉDIO REVENDA (dólares)               6.972
# Name: 1, dtype: object

# %% [markdown]
# **Selecionando múltiplias amostras(observações)/linhas:**

# %%
# selecionando as linhas de índice de 0 a 5 (incluso)
data.iloc[:6]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
# 5                1.383                  0.132  ...                     0.957
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
# 5                       0.128                    0.5686
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
# 5                       1.35                         0.134   5  2004
#
#   coluna sem nocao coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0          DEFAULT                        0                          7.728
# 1          DEFAULT                        1                          6.972
# 2          DEFAULT                        2                          8.334
# 3          DEFAULT                        3                          7.572
# 4          DEFAULT                        4                          7.086
# 5          DEFAULT                        5                          8.298
#
# [6 rows x 24 columns]

# %%
# Selecionando as linhas de índice de 10 a 15 (15 incluso)
data.iloc[10:16]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 10          10   2004-05-09  2004-05-15  NORDESTE                PIAUI
# 11          11   2004-05-09  2004-05-15  NORDESTE  RIO GRANDE DO NORTE
# 12          12   2004-05-09  2004-05-15  NORDESTE              SERGIPE
# 13          13   2004-05-09  2004-05-15     NORTE                 ACRE
# 14          14   2004-05-09  2004-05-15     NORTE                AMAPA
# 15          15   2004-05-09  2004-05-15     NORTE             AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 10  ETANOL HIDRATADO                            89              R$/l
# 11  ETANOL HIDRATADO                           131              R$/l
# 12  ETANOL HIDRATADO                            57              R$/l
# 13  ETANOL HIDRATADO                            33              R$/l
# 14  ETANOL HIDRATADO                            15              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 10                1.573                  0.134  ...                     1.079
# 11                1.276                  0.116  ...                     0.944
# 12                1.301                  0.109  ...                      0.98
# 13                1.805                  0.134  ...                     1.116
# 14                1.785                  0.035  ...                     1.373
# 15                1.578                  0.123  ...                     1.137
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 10                       0.078                    0.8857
# 11                       0.078                    0.7119
# 12                       0.052                    0.8267
# 13                       0.171                     0.767
# 14                       0.167                    0.8339
# 15                       0.068                    0.9515
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 10                     1.2499                         0.072   5  2004
# 11                     1.1386                         0.083   5  2004
# 12                     1.1059                         0.053   5  2004
# 13                     1.2992                         0.153   5  2004
# 14                     1.4912                         0.122   5  2004
# 15                     1.2109                          0.06   5  2004
#
#    coluna sem nocao coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 10          DEFAULT                       10                          9.438
# 11          DEFAULT                       11                          7.656
# 12          DEFAULT                       12                          7.806
# 13          DEFAULT                       13                         10.830
# 14          DEFAULT                       14                         10.710
# 15          DEFAULT                       15                          9.468
#
# [6 rows x 24 columns]

# %%
# Selecionando as linhas/amostra(observações) de índice 1, 5, 10, 15 - para isto vamos passar uma lista com esses índices
data.iloc[[1, 5, 10, 15]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1   ETANOL HIDRATADO                           387              R$/l
# 5   ETANOL HIDRATADO                           408              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                 1.162                  0.114  ...                     0.763
# 5                 1.383                  0.132  ...                     0.957
# 10                1.573                  0.134  ...                     1.079
# 15                1.578                  0.123  ...                     1.137
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1                        0.088                    0.5013
# 5                        0.128                    0.5686
# 10                       0.078                    0.8857
# 15                       0.068                    0.9515
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 1                        1.05                         0.115   5  2004
# 5                        1.35                         0.134   5  2004
# 10                     1.2499                         0.072   5  2004
# 15                     1.2109                          0.06   5  2004
#
#    coluna sem nocao coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 1           DEFAULT                        1                          6.972
# 5           DEFAULT                        5                          8.298
# 10          DEFAULT                       10                          9.438
# 15          DEFAULT                       15                          9.468
#
# [4 rows x 24 columns]

# %%
# Podemos selecionar os mesmos índices fora de ordem ou em qualquer ordem. 5, 1, 15, 10
data.iloc[[5, 1, 15, 10]]
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5   ETANOL HIDRATADO                           408              R$/l
# 1   ETANOL HIDRATADO                           387              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 5                 1.383                  0.132  ...                     0.957
# 1                 1.162                  0.114  ...                     0.763
# 15                1.578                  0.123  ...                     1.137
# 10                1.573                  0.134  ...                     1.079
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 5                        0.128                    0.5686
# 1                        0.088                    0.5013
# 15                       0.068                    0.9515
# 10                       0.078                    0.8857
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 5                        1.35                         0.134   5  2004
# 1                        1.05                         0.115   5  2004
# 15                     1.2109                          0.06   5  2004
# 10                     1.2499                         0.072   5  2004
#
#    coluna sem nocao coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 5           DEFAULT                        5                          8.298
# 1           DEFAULT                        1                          6.972
# 15          DEFAULT                       15                          9.468
# 10          DEFAULT                       10                          9.438
#
# [4 rows x 24 columns]

# %%
# Retornar o valor da linha de índice 1, coluna 4 ('ESTADO')
data.iloc[1, 4]
# Out:
# 'GOIAS'

# %%
# e assim por diante!

# %% [markdown]
# #### **==>  Label-based selection (seleção baseadas em Rótulos)**
#
# `loc`: seleciona elementos do Dataframe, baseado em seus **rótulos** --> row-first, column-second

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# Retorna a linha de índice 0 (implícito) ===> usando o iloc
pesquisa_de_satisfacao.iloc[0] # retorna os resultados da linha 1 (50, 131, 30)
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# Retorna o valor da linha de índice 0 (implícito) e coluna de índice 1 (implícito) ===> usando o iloc
pesquisa_de_satisfacao.iloc[0, 1] # retorna 131
# Out:
# 131

# %%
# Retorna a linha cujo o rótulo do índice é 'XboxOne'ArithmeticError
pesquisa_de_satisfacao.loc['XboxOne'] # Retorna 50, 131, 30
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# Forma que NÃO FUNCIONA ===> iloc tentando acessar índices com rótulos
# pesquisa_de_satisfacao.iloc['XboxOne'] # Retorna erro

# %%
# Forma que NÃO FUNCIONA ===> loc tentando acessar índices com rotulados com números
pesquisa_de_satisfacao.iloc[0]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# Uso de loc para linha 'Playstation4' e coluna 'ruim'
pesquisa_de_satisfacao.loc['Playstation4', 'ruim']
# Out:
# 2

# %%
# Selecionando as linhas de índices rotulados 'XboxOne', 'Switch'
pesquisa_de_satisfacao.loc[['XboxOne', 'Switch']]
# Out:
#          bom  ruim  pessimo
# XboxOne   50   131       30
# Switch   100    30        1

# %%
# Retorna todas as linhas e apenas as colunas com rótulos 'bom' e 'péssimo'
pesquisa_de_satisfacao[['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %%
# Usando loc
pesquisa_de_satisfacao.loc[:, ['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %% [markdown]
# #### OBSERVAÇÃO
#
# **ïndices Númericos**, por default, possuem **rótulos que correspondem aos seus valores númericos.**

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   coluna sem nocao coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0          DEFAULT                        0                          7.728
# 1          DEFAULT                        1                          6.972
# 2          DEFAULT                        2                          8.334
# 3          DEFAULT                        3                          7.572
# 4          DEFAULT                        4                          7.086
#
# [5 rows x 24 columns]

# %%
data.loc[1] # Nesse caso, funciona o númerico porque tem uma coluna númerica com índice 1
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# coluna sem nocao                          DEFAULT
# coluna a partir de lista                        1
# PREÇO MÉDIO REVENDA (dólares)               6.972
# Name: 1, dtype: object

# %% [markdown]
# ### 1.5 Selecionando um ou mais atributos (colunas)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   coluna sem nocao coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0          DEFAULT                        0                          7.728
# 1          DEFAULT                        1                          6.972
# 2          DEFAULT                        2                          8.334
# 3          DEFAULT                        3                          7.572
# 4          DEFAULT                        4                          7.086
#
# [5 rows x 24 columns]

# %%
# Retornando a coluna/atributo 'ESTADO'
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
# A forma de acesso de colunas por .NOME_DA_COLUNA só funciona se 
# NOME_DA_COLUNA não possuir caracteres inválidos (espaços, acentos, cedilha, etc.)
# data. DATA INICIAL não funciona
data.ESTADO
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.loc[:, 'ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
# Para colunas cujos rótulo possuem caracteres inválidos,
# São válidas as soluções por string ou loc
data.loc[:, 'DATA INICIAL'] # ou data['DATA INCIAL']
# Out:
# 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 106818    2019-06-23
# 106819    2019-06-23
# 106820    2019-06-23
# 106821    2019-06-23
# 106822    2019-06-23
# Name: DATA INICIAL, Length: 106823, dtype: object

# %%
# Selecionando múltiplas colunas: 'PRODUTO', 'ESTADO', 'REGIÃO'
data[['PRODUTO', 'ESTADO', 'REGIÃO']]
# Out:
#                  PRODUTO               ESTADO        REGIÃO
# 0       ETANOL HIDRATADO     DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO                GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO          MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO   MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO              ALAGOAS      NORDESTE
# ...                  ...                  ...           ...
# 106818               GNV  RIO GRANDE DO NORTE      NORDESTE
# 106819               GNV    RIO GRANDE DO SUL           SUL
# 106820               GNV       SANTA CATARINA           SUL
# 106821               GNV            SAO PAULO       SUDESTE
# 106822               GNV              SERGIPE      NORDESTE
#
# [106823 rows x 3 columns]

# %% [markdown]
# Como o rótulo da coluna 'DATA INICIAL' **possui espaço**, não é possível acessá-la como método: `data.DATA INICIAL`

# %% [markdown]
# ### 1.6 Removendo um Atributo (Coluna) do Data Frame

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#   coluna sem nocao coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0          DEFAULT                        0                          7.728
# 1          DEFAULT                        1                          6.972
# 2          DEFAULT                        2                          8.334
# 3          DEFAULT                        3                          7.572
# 4          DEFAULT                        4                          7.086
#
# [5 rows x 24 columns]

# %% [markdown]
# Como vimos anteriormente, o atributo 'Unnamed: 0' parece ser um **ruído** em nosso dataset. Desta maneira, vamos eliminá-lo,

# %%
# Deleta/remova in-place (ou seja, no próprio dataframe) a coluna de rótulo 'Unnamed: 0'
del data['Unnamed: 0']

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 106818                3.574                  0.065                 3.499  ...
# 106819                3.401                  0.129                 3.230  ...
# 106820                2.912                  0.190                 2.699  ...
# 106821                3.020                  0.229                 2.699  ...
# 106822                3.697                  0.005                 3.689  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.9666
# 1                          0.5013                      1.05
# 2                          0.5614                     1.161
# 3                          0.5991                   1.22242
# 4                          0.7441                    1.0317
# ...                           ...                       ...
# 106818                      2.756                     2.756
# 106819                     1.9842                    2.8661
# 106820                     1.9981                    1.9981
# 106821                     2.0179                    2.5093
# 106822                     2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                              0.133   5  2004          DEFAULT
# 1                              0.115   5  2004          DEFAULT
# 2                              0.098   5  2004          DEFAULT
# 3                              0.143   5  2004          DEFAULT
# 4                              0.082   5  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106818                             0   6  2019          DEFAULT
# 106819                         0.164   6  2019          DEFAULT
# 106820                             0   6  2019          DEFAULT
# 106821                          0.07   6  2019          DEFAULT
# 106822                             0   6  2019          DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                              0                          7.728
# 1                              1                          6.972
# 2                              2                          8.334
# 3                              3                          7.572
# 4                              4                          7.086
# ...                          ...                            ...
# 106818                    106818                         21.444
# 106819                    106819                         20.406
# 106820                    106820                         17.472
# 106821                    106821                         18.120
# 106822                    106822                         22.182
#
# [106823 rows x 23 columns]

# %% [markdown]
# Vamos agora remover as colunas fictícias cridas nos vídeos anteriores

# %%
# del data['coluna sem nocao']
# del data['coluna a partir da lista']
# del data['PREÇO MÉDIO REVENDA (dolares)']

# %% [markdown]
# ### 1.7 Salvando um Data Frame

# %% [markdown]
# Para salvarmos um Data Frame para um **arquivo CSV**, basta usarmos o método `.to_csv`. <br/>
# Por padrão, esse método **salva os índices da tabela como uma coluna no CSV**.<br/>
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso (veja que removemos anteriormente a coluna 'Unnamed: 0' que foi justamente esse caso).<br/>
# Desta forma, utilize o parâmetro: `index=False`.
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro `sep`.

# %%
data.to_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado.csv', index=False, sep=',')

# %% [markdown]
# ### 1.8 Seleção Condicional: Filtrando amostras

# %% [markdown]
# Durante nossas análise exploratórias, frequentemente filtraremos nossas amostras, a partir de certas **condições**, para fins de análise mais específica. <br/>
# Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nosso dataset pré-processado que salvamos no item anterior.

# %%
data = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado.csv')

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                         0.133   5  2004          DEFAULT
# 1                         0.115   5  2004          DEFAULT
# 2                         0.098   5  2004          DEFAULT
# 3                         0.143   5  2004          DEFAULT
# 4                         0.082   5  2004          DEFAULT
#
#    coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                         0                          7.728
# 1                         1                          6.972
# 2                         2                          8.334
# 3                         3                          7.572
# 4                         4                          7.086
#
# [5 rows x 23 columns]

# %%
# Mostra todos os estados cujos os preços dos combustíveis foram aferidos
# Mais tecnicamente, mostra os valores únicos presentes para a coluna 'ESTADO'
data['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
# Para calcular o número de valores únicos da coluna, usa-se o nunique
data['ESTADO'].nunique() # 27
# Out:
# 27

# %% [markdown]
# #### **Selecionando apenas os preços dos Postos de São Paulo**

# %% [markdown]
# ##### **==> Alternativa 1: Seleção Condicional (Comparações diretas)**

# %% [markdown]
# O código abaixo retorna uma ***Series ('array') de booleans***, com o número de linhas (amostras) do Data Frame, que informa os registros de preços dos postos do _estado de São Paulo_ (True).

# %%
# Faz uma comparação elemento a elemento da Series, retornando uma Series de booleans 
data['ESTADO'] == 'SAO PAULO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
# Salvando esta Series de booleans em uma variável
selecao = data['ESTADO'] == 'SAO PAULO'

# %%
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
type(selecao)
# Out:
# pandas.core.series.Series

# %%
selecao.shape
# Out:
# (106823,)

# %%
data.shape
# Out:
# (106823, 23)

# %% [markdown]
# Para **filtrarmos** os registros de postos do estado de São Paulo:

# %%
data[selecao]    # ou data[data['ESTADO'] == 'SAO PAULO']
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                          0.57                      0.056
# 50                         0.576                       0.05
# 77                         0.614                      0.063
# 104                        0.671                      0.075
# 131                        0.689                      0.072
# ...                          ...                        ...
# 106724                     3.047                      0.097
# 106751                     3.123                      0.111
# 106778                     3.713                      0.097
# 106805                    49.214                      5.071
# 106821                     2.374                      0.165
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                         0.4271                    1.4123
# 50                        0.43204                    0.9724
# 77                        0.34951                     1.412
# 104                        0.3398                    1.0669
# 131                       0.47797                    1.0669
# ...                           ...                       ...
# 106724                     2.8599                    3.3481
# 106751                      2.885                     3.491
# 106778                       3.52                    4.0892
# 106805                      40.19                        72
# 106821                     2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 23                             0.098   5  2004          DEFAULT
# 50                             0.087   5  2004          DEFAULT
# 77                             0.103   5  2004          DEFAULT
# 104                            0.112   5  2004          DEFAULT
# 131                            0.104   6  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106724                         0.032   6  2019          DEFAULT
# 106751                         0.036   6  2019          DEFAULT
# 106778                         0.026   6  2019          DEFAULT
# 106805                         0.103   6  2019          DEFAULT
# 106821                          0.07   6  2019          DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 23                            23                          4.608
# 50                            50                          4.596
# 77                            77                          4.938
# 104                          104                          5.322
# 131                          131                          5.364
# ...                          ...                            ...
# 106724                    106724                         20.688
# 106751                    106751                         21.444
# 106778                    106778                         24.852
# 106805                    106805                        401.358
# 106821                    106821                         18.120
#
# [4263 rows x 23 columns]

# %% [markdown]
# O resultado é um Data Frame com _apenas_ os registros desejados após a **filtragem**.<br/>
# Podemos ainda utilizar o método `loc` para o mesmo fim:

# %%
data.loc[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                          0.57                      0.056
# 50                         0.576                       0.05
# 77                         0.614                      0.063
# 104                        0.671                      0.075
# 131                        0.689                      0.072
# ...                          ...                        ...
# 106724                     3.047                      0.097
# 106751                     3.123                      0.111
# 106778                     3.713                      0.097
# 106805                    49.214                      5.071
# 106821                     2.374                      0.165
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                         0.4271                    1.4123
# 50                        0.43204                    0.9724
# 77                        0.34951                     1.412
# 104                        0.3398                    1.0669
# 131                       0.47797                    1.0669
# ...                           ...                       ...
# 106724                     2.8599                    3.3481
# 106751                      2.885                     3.491
# 106778                       3.52                    4.0892
# 106805                      40.19                        72
# 106821                     2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 23                             0.098   5  2004          DEFAULT
# 50                             0.087   5  2004          DEFAULT
# 77                             0.103   5  2004          DEFAULT
# 104                            0.112   5  2004          DEFAULT
# 131                            0.104   6  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106724                         0.032   6  2019          DEFAULT
# 106751                         0.036   6  2019          DEFAULT
# 106778                         0.026   6  2019          DEFAULT
# 106805                         0.103   6  2019          DEFAULT
# 106821                          0.07   6  2019          DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 23                            23                          4.608
# 50                            50                          4.596
# 77                            77                          4.938
# 104                          104                          5.322
# 131                          131                          5.364
# ...                          ...                            ...
# 106724                    106724                         20.688
# 106751                    106751                         21.444
# 106778                    106778                         24.852
# 106805                    106805                        401.358
# 106821                    106821                         18.120
#
# [4263 rows x 23 columns]

# %% [markdown]
# ##### **==> Alternativa 2: Utilizando o método `query`**

# %% [markdown]
# `query` filtra linhas de um DataFrame baseado em uma **query (pergunta)**.

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                         0.133   5  2004          DEFAULT
# 1                         0.115   5  2004          DEFAULT
# 2                         0.098   5  2004          DEFAULT
# 3                         0.143   5  2004          DEFAULT
# 4                         0.082   5  2004          DEFAULT
#
#    coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                         0                          7.728
# 1                         1                          6.972
# 2                         2                          8.334
# 3                         3                          7.572
# 4                         4                          7.086
#
# [5 rows x 23 columns]

# %% [markdown]
# <br/>
#
# Uma boa prática é **salvar o Data Frame filtrado em uma nova variável**. Isso simplifica a complexidade do código para futuras análise feitas para os postos de São Paulo (neste caso).

# %%
postos_sp = data.query('ESTADO == "SAO PAULO"')

# %%
postos_sp.head()
# Out:
#     DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23    2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50    2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77    2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                           4047              R$/l                0.768
# 50                           4066              R$/l                0.766
# 77                           4077              R$/l                0.823
# 104                          4073              R$/l                0.887
# 131                          4082              R$/l                0.894
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                   0.085                 0.590  ...
# 50                   0.083                 0.590  ...
# 77                   0.071                 0.620  ...
# 104                  0.075                 0.639  ...
# 131                  0.071                 0.669  ...
#
#      PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                       0.57                      0.056
# 50                      0.576                       0.05
# 77                      0.614                      0.063
# 104                     0.671                      0.075
# 131                     0.689                      0.072
#
#      PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                      0.4271                    1.4123
# 50                     0.43204                    0.9724
# 77                     0.34951                     1.412
# 104                     0.3398                    1.0669
# 131                    0.47797                    1.0669
#
#     COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 23                          0.098   5  2004          DEFAULT
# 50                          0.087   5  2004          DEFAULT
# 77                          0.103   5  2004          DEFAULT
# 104                         0.112   5  2004          DEFAULT
# 131                         0.104   6  2004          DEFAULT
#
#      coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 23                         23                          4.608
# 50                         50                          4.596
# 77                         77                          4.938
# 104                       104                          5.322
# 131                       131                          5.364
#
# [5 rows x 23 columns]

# %%
type(postos_sp)
# Out:
# pandas.core.frame.DataFrame

# %%
postos_sp.shape
# Out:
# (4263, 23)

# %% [markdown]
# #### Resetando os índices
#
# Note que os _índices_ das _linhas/registros_ após a _filtragem_ **continumas sendo os mesmos** do DataFrame original.
# Em muitas situações, manter esta informação será importante.
#
# Mas, se você quiser **resetar os índices** do dataframe filtrado, fazendo com que os registros comecem com __índice 0 até num_linhas-1__, use o método `.reset_index`

# %%
postos_sp.reset_index(drop=True)
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4258                           863              R$/l                3.448
# 4259                          1277              R$/l                3.574
# 4260                          1644              R$/l                4.142
# 4261                          1017           R$/13Kg               66.893
# 4262                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     0.085                 0.590  ...
# 1                     0.083                 0.590  ...
# 2                     0.071                 0.620  ...
# 3                     0.075                 0.639  ...
# 4                     0.071                 0.669  ...
# ...                     ...                   ...  ...
# 4258                  0.156                 3.099  ...
# 4259                  0.169                 3.199  ...
# 4260                  0.183                 3.769  ...
# 4261                  6.100                50.000  ...
# 4262                  0.229                 2.699  ...
#
#       PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.57                      0.056
# 1                        0.576                       0.05
# 2                        0.614                      0.063
# 3                        0.671                      0.075
# 4                        0.689                      0.072
# ...                        ...                        ...
# 4258                     3.047                      0.097
# 4259                     3.123                      0.111
# 4260                     3.713                      0.097
# 4261                    49.214                      5.071
# 4262                     2.374                      0.165
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                        0.4271                    1.4123
# 1                       0.43204                    0.9724
# 2                       0.34951                     1.412
# 3                        0.3398                    1.0669
# 4                       0.47797                    1.0669
# ...                         ...                       ...
# 4258                     2.8599                    3.3481
# 4259                      2.885                     3.491
# 4260                       3.52                    4.0892
# 4261                      40.19                        72
# 4262                     2.0179                    2.5093
#
#      COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                            0.098   5  2004          DEFAULT
# 1                            0.087   5  2004          DEFAULT
# 2                            0.103   5  2004          DEFAULT
# 3                            0.112   5  2004          DEFAULT
# 4                            0.104   6  2004          DEFAULT
# ...                            ...  ..   ...              ...
# 4258                         0.032   6  2019          DEFAULT
# 4259                         0.036   6  2019          DEFAULT
# 4260                         0.026   6  2019          DEFAULT
# 4261                         0.103   6  2019          DEFAULT
# 4262                          0.07   6  2019          DEFAULT
#
#       coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                           23                          4.608
# 1                           50                          4.596
# 2                           77                          4.938
# 3                          104                          5.322
# 4                          131                          5.364
# ...                        ...                            ...
# 4258                    106724                         20.688
# 4259                    106751                         21.444
# 4260                    106778                         24.852
# 4261                    106805                        401.358
# 4262                    106821                         18.120
#
# [4263 rows x 23 columns]

# %%
# Ainda não foi alterado, precisamos usar o atributo/parâmetro inplace=True
postos_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 23                      0.085                 0.590  ...
# 50                      0.083                 0.590  ...
# 77                      0.071                 0.620  ...
# 104                     0.075                 0.639  ...
# 131                     0.071                 0.669  ...
# ...                       ...                   ...  ...
# 106724                  0.156                 3.099  ...
# 106751                  0.169                 3.199  ...
# 106778                  0.183                 3.769  ...
# 106805                  6.100                50.000  ...
# 106821                  0.229                 2.699  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                          0.57                      0.056
# 50                         0.576                       0.05
# 77                         0.614                      0.063
# 104                        0.671                      0.075
# 131                        0.689                      0.072
# ...                          ...                        ...
# 106724                     3.047                      0.097
# 106751                     3.123                      0.111
# 106778                     3.713                      0.097
# 106805                    49.214                      5.071
# 106821                     2.374                      0.165
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                         0.4271                    1.4123
# 50                        0.43204                    0.9724
# 77                        0.34951                     1.412
# 104                        0.3398                    1.0669
# 131                       0.47797                    1.0669
# ...                           ...                       ...
# 106724                     2.8599                    3.3481
# 106751                      2.885                     3.491
# 106778                       3.52                    4.0892
# 106805                      40.19                        72
# 106821                     2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 23                             0.098   5  2004          DEFAULT
# 50                             0.087   5  2004          DEFAULT
# 77                             0.103   5  2004          DEFAULT
# 104                            0.112   5  2004          DEFAULT
# 131                            0.104   6  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106724                         0.032   6  2019          DEFAULT
# 106751                         0.036   6  2019          DEFAULT
# 106778                         0.026   6  2019          DEFAULT
# 106805                         0.103   6  2019          DEFAULT
# 106821                          0.07   6  2019          DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 23                            23                          4.608
# 50                            50                          4.596
# 77                            77                          4.938
# 104                          104                          5.322
# 131                          131                          5.364
# ...                          ...                            ...
# 106724                    106724                         20.688
# 106751                    106751                         21.444
# 106778                    106778                         24.852
# 106805                    106805                        401.358
# 106821                    106821                         18.120
#
# [4263 rows x 23 columns]

# %%
postos_sp.reset_index(drop=True, inplace=True)

# %%
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4258                           863              R$/l                3.448
# 4259                          1277              R$/l                3.574
# 4260                          1644              R$/l                4.142
# 4261                          1017           R$/13Kg               66.893
# 4262                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     0.085                 0.590  ...
# 1                     0.083                 0.590  ...
# 2                     0.071                 0.620  ...
# 3                     0.075                 0.639  ...
# 4                     0.071                 0.669  ...
# ...                     ...                   ...  ...
# 4258                  0.156                 3.099  ...
# 4259                  0.169                 3.199  ...
# 4260                  0.183                 3.769  ...
# 4261                  6.100                50.000  ...
# 4262                  0.229                 2.699  ...
#
#       PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.57                      0.056
# 1                        0.576                       0.05
# 2                        0.614                      0.063
# 3                        0.671                      0.075
# 4                        0.689                      0.072
# ...                        ...                        ...
# 4258                     3.047                      0.097
# 4259                     3.123                      0.111
# 4260                     3.713                      0.097
# 4261                    49.214                      5.071
# 4262                     2.374                      0.165
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                        0.4271                    1.4123
# 1                       0.43204                    0.9724
# 2                       0.34951                     1.412
# 3                        0.3398                    1.0669
# 4                       0.47797                    1.0669
# ...                         ...                       ...
# 4258                     2.8599                    3.3481
# 4259                      2.885                     3.491
# 4260                       3.52                    4.0892
# 4261                      40.19                        72
# 4262                     2.0179                    2.5093
#
#      COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                            0.098   5  2004          DEFAULT
# 1                            0.087   5  2004          DEFAULT
# 2                            0.103   5  2004          DEFAULT
# 3                            0.112   5  2004          DEFAULT
# 4                            0.104   6  2004          DEFAULT
# ...                            ...  ..   ...              ...
# 4258                         0.032   6  2019          DEFAULT
# 4259                         0.036   6  2019          DEFAULT
# 4260                         0.026   6  2019          DEFAULT
# 4261                         0.103   6  2019          DEFAULT
# 4262                          0.07   6  2019          DEFAULT
#
#       coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                           23                          4.608
# 1                           50                          4.596
# 2                           77                          4.938
# 3                          104                          5.322
# 4                          131                          5.364
# ...                        ...                            ...
# 4258                    106724                         20.688
# 4259                    106751                         21.444
# 4260                    106778                         24.852
# 4261                    106805                        401.358
# 4262                    106821                         18.120
#
# [4263 rows x 23 columns]

# %%
# ALTERNATIVA MUITO COMUM
postos_sp = data.query('ESTADO == "SAO PAULO"').reset_index(drop=True)
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4258                           863              R$/l                3.448
# 4259                          1277              R$/l                3.574
# 4260                          1644              R$/l                4.142
# 4261                          1017           R$/13Kg               66.893
# 4262                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     0.085                 0.590  ...
# 1                     0.083                 0.590  ...
# 2                     0.071                 0.620  ...
# 3                     0.075                 0.639  ...
# 4                     0.071                 0.669  ...
# ...                     ...                   ...  ...
# 4258                  0.156                 3.099  ...
# 4259                  0.169                 3.199  ...
# 4260                  0.183                 3.769  ...
# 4261                  6.100                50.000  ...
# 4262                  0.229                 2.699  ...
#
#       PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.57                      0.056
# 1                        0.576                       0.05
# 2                        0.614                      0.063
# 3                        0.671                      0.075
# 4                        0.689                      0.072
# ...                        ...                        ...
# 4258                     3.047                      0.097
# 4259                     3.123                      0.111
# 4260                     3.713                      0.097
# 4261                    49.214                      5.071
# 4262                     2.374                      0.165
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                        0.4271                    1.4123
# 1                       0.43204                    0.9724
# 2                       0.34951                     1.412
# 3                        0.3398                    1.0669
# 4                       0.47797                    1.0669
# ...                         ...                       ...
# 4258                     2.8599                    3.3481
# 4259                      2.885                     3.491
# 4260                       3.52                    4.0892
# 4261                      40.19                        72
# 4262                     2.0179                    2.5093
#
#      COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                            0.098   5  2004          DEFAULT
# 1                            0.087   5  2004          DEFAULT
# 2                            0.103   5  2004          DEFAULT
# 3                            0.112   5  2004          DEFAULT
# 4                            0.104   6  2004          DEFAULT
# ...                            ...  ..   ...              ...
# 4258                         0.032   6  2019          DEFAULT
# 4259                         0.036   6  2019          DEFAULT
# 4260                         0.026   6  2019          DEFAULT
# 4261                         0.103   6  2019          DEFAULT
# 4262                          0.07   6  2019          DEFAULT
#
#       coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                           23                          4.608
# 1                           50                          4.596
# 2                           77                          4.938
# 3                          104                          5.322
# 4                          131                          5.364
# ...                        ...                            ...
# 4258                    106724                         20.688
# 4259                    106751                         21.444
# 4260                    106778                         24.852
# 4261                    106805                        401.358
# 4262                    106821                         18.120
#
# [4263 rows x 23 columns]

# %% [markdown]
# #### **Selecionando registros de postos do Rio de Janeiro com Preços acima de 2 reais**

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                         0.133   5  2004          DEFAULT
# 1                         0.115   5  2004          DEFAULT
# 2                         0.098   5  2004          DEFAULT
# 3                         0.143   5  2004          DEFAULT
# 4                         0.082   5  2004          DEFAULT
#
#    coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                         0                          7.728
# 1                         1                          6.972
# 2                         2                          8.334
# 3                         3                          7.572
# 4                         4                          7.086
#
# [5 rows x 23 columns]

# %%
data['ESTADO'] == 'RIO DE JANEIRO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
data['PREÇO MÉDIO REVENDA'] > 2.0
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818     True
# 106819     True
# 106820     True
# 106821     True
# 106822     True
# Name: PREÇO MÉDIO REVENDA, Length: 106823, dtype: bool

# %%
# Como data['ESTADO'] == 'RIO DE JANEIRO' e data['PREÇO MÉDIO REVENDA'] > 2.0 possuem o mesmo número de linhas, é possível juntar as duas, assim...
selecao = (data['ESTADO'] == 'RIO DE JANEIRO') & (data['PREÇO MÉDIO REVENDA'] > 2.0)
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %% [markdown]
# Note que o resultado da seleção continua sendo uma _Series de booleans_ com o _mesmo número de linhas/amostras do DataFrame_, de modo que cada linha possuirá um valor booleano indicando se o posto é do Rio de Janeiro **E** o preço aferido do combustível é maior que 2 reais (True) ou não.
#
# O símbolo **&** significa **AND** na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&). <br/>
# Similarmente:
# - **|** representa o **OR** (não é ||)
# - **~** representa o **NOT** (não é !)

# %%
data[selecao] # mostrando apenas os valores True para selecao (ou postos do rio de janeiro com valor maior que 2.0)
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 2501                             881              R$/l                2.028
# 2528                             889              R$/l                2.125
# 2555                             902              R$/l                2.163
# 2582                             898              R$/l                2.166
# 2609                             890              R$/l                2.172
# ...                              ...               ...                  ...
# 106718                           212              R$/l                3.569
# 106745                           335              R$/l                3.697
# 106772                           422              R$/l                4.928
# 106799                           221           R$/13Kg               65.010
# 106817                           124             R$/m3                3.111
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 2501                    0.148                 1.589  ...
# 2528                    0.149                 1.779  ...
# 2555                    0.138                 1.799  ...
# 2582                    0.146                 1.760  ...
# 2609                    0.143                 1.789  ...
# ...                       ...                   ...  ...
# 106718                  0.166                 3.179  ...
# 106745                  0.187                 3.279  ...
# 106772                  0.165                 4.599  ...
# 106799                  5.812                50.000  ...
# 106817                  0.260                 2.799  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 2501                       1.806                       0.11
# 2528                       1.839                      0.117
# 2555                       1.895                      0.134
# 2582                       1.935                       0.14
# 2609                       1.963                      0.133
# ...                          ...                        ...
# 106718                     3.102                      0.119
# 106745                     3.197                      0.127
# 106772                      4.39                      0.097
# 106799                    47.535                      3.934
# 106817                     2.404                      0.174
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 2501                         1.31                    2.1358
# 2528                        1.438                    2.2801
# 2555                         1.43                    2.3454
# 2582                        1.438                    2.2925
# 2609                        1.438                    2.2513
# ...                           ...                       ...
# 106718                      2.886                    3.5162
# 106745                     2.9772                    3.5388
# 106772                        4.2                     4.618
# 106799                         39                      58.2
# 106817                      2.126                    2.7909
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 2501                           0.061   2  2006          DEFAULT
# 2528                           0.064   3  2006          DEFAULT
# 2555                           0.071   3  2006          DEFAULT
# 2582                           0.072   3  2006          DEFAULT
# 2609                           0.068   3  2006          DEFAULT
# ...                              ...  ..   ...              ...
# 106718                         0.038   6  2019          DEFAULT
# 106745                          0.04   6  2019          DEFAULT
# 106772                         0.022   6  2019          DEFAULT
# 106799                         0.083   6  2019          DEFAULT
# 106817                         0.072   6  2019          DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 2501                        2501                         12.168
# 2528                        2528                         12.750
# 2555                        2555                         12.978
# 2582                        2582                         12.996
# 2609                        2609                         13.032
# ...                          ...                            ...
# 106718                    106718                         21.414
# 106745                    106745                         22.182
# 106772                    106772                         29.568
# 106799                    106799                        390.060
# 106817                    106817                         18.666
#
# [3054 rows x 23 columns]

# %% [markdown]
# Alternativamente, poderíamos usar o método `query` para fazermos tal seleção. Porém, isso não é possível especificamente para esse caso, pois o rótulo da coluna 'PREÇO MÉDIO REVENDA' possui caracteres inválidos para o método (cedilha, acentos)

# %%
# Não funciona
# data.query('ESTADO=="RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')

# %% [markdown]
# **Aprofundando mais ainda**
#
# A primeira comparação `(data['ESTADO'] == 'RIO DE JANEIRO')` checa, linha a linha (observação a observação) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# A segunda comparação `(data['PREÇO MÉDIO REVENDA'] > 2)` checa, linha a linha (observação a observação) do DataFrame, quais são os registros cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de **TODOS os estados**. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.

# %% [markdown]
# Alguns podem argumentar que tal abordagem é **ineficiente**, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame. <br/>
# O Pandas _tenta otimizar_ isso ao máximo por de trás dos panos. Mas, de fato, se tivermos um dataset **muito grande** (centenas de milhares de linhas), tal abordagem se tornará _lenta_.

# %% [markdown]
# Assim, poderíamos fazer filtragem com múltiplos condicionais em partes:

# %%
selecao_1 = data['ESTADO'] == 'RIO DE JANEIRO'
postos_rj = data[selecao_1]
postos_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 103      2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 130      2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 22                               952              R$/l                1.098
# 49                               948              R$/l                1.092
# 76                               973              R$/l                1.103
# 103                              955              R$/l                1.149
# 130                              966              R$/l                1.165
# ...                              ...               ...                  ...
# 106718                           212              R$/l                3.569
# 106745                           335              R$/l                3.697
# 106772                           422              R$/l                4.928
# 106799                           221           R$/13Kg               65.010
# 106817                           124             R$/m3                3.111
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 22                      0.154                 0.740  ...
# 49                      0.157                 0.740  ...
# 76                      0.140                 0.770  ...
# 103                     0.156                 0.799  ...
# 130                     0.154                 0.830  ...
# ...                       ...                   ...  ...
# 106718                  0.166                 3.179  ...
# 106745                  0.187                 3.279  ...
# 106772                  0.165                 4.599  ...
# 106799                  5.812                50.000  ...
# 106817                  0.260                 2.799  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 22                         0.786                      0.173
# 49                         0.808                      0.175
# 76                         0.822                      0.166
# 103                        0.849                      0.188
# 130                        0.911                      0.198
# ...                          ...                        ...
# 106718                     3.102                      0.119
# 106745                     3.197                      0.127
# 106772                      4.39                      0.097
# 106799                    47.535                      3.934
# 106817                     2.404                      0.174
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 22                          0.326                     1.263
# 49                         0.3257                    1.2921
# 76                        0.38909                    1.1859
# 103                        0.3453                    1.3667
# 130                           0.4                    1.3667
# ...                           ...                       ...
# 106718                      2.886                    3.5162
# 106745                     2.9772                    3.5388
# 106772                        4.2                     4.618
# 106799                         39                      58.2
# 106817                      2.126                    2.7909
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 22                              0.22   5  2004          DEFAULT
# 49                             0.217   5  2004          DEFAULT
# 76                             0.202   5  2004          DEFAULT
# 103                            0.221   5  2004          DEFAULT
# 130                            0.217   6  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106718                         0.038   6  2019          DEFAULT
# 106745                          0.04   6  2019          DEFAULT
# 106772                         0.022   6  2019          DEFAULT
# 106799                         0.083   6  2019          DEFAULT
# 106817                         0.072   6  2019          DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 22                            22                          6.588
# 49                            49                          6.552
# 76                            76                          6.618
# 103                          103                          6.894
# 130                          130                          6.990
# ...                          ...                            ...
# 106718                    106718                         21.414
# 106745                    106745                         22.182
# 106772                    106772                         29.568
# 106799                    106799                        390.060
# 106817                    106817                         18.666
#
# [4263 rows x 23 columns]

# %%
selecao_2 = postos_rj['PREÇO MÉDIO REVENDA'] > 2.0
selecao_2
# Out:
# 22        False
# 49        False
# 76        False
# 103       False
# 130       False
#           ...
# 106718     True
# 106745     True
# 106772     True
# 106799     True
# 106817     True
# Name: PREÇO MÉDIO REVENDA, Length: 4263, dtype: bool

# %%
postos_rj_preco_maior_que_2 = postos_rj[selecao_2]
postos_rj_preco_maior_que_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 2501     2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2528     2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2555     2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2582     2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 2609     2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 2501                             881              R$/l                2.028
# 2528                             889              R$/l                2.125
# 2555                             902              R$/l                2.163
# 2582                             898              R$/l                2.166
# 2609                             890              R$/l                2.172
# ...                              ...               ...                  ...
# 106718                           212              R$/l                3.569
# 106745                           335              R$/l                3.697
# 106772                           422              R$/l                4.928
# 106799                           221           R$/13Kg               65.010
# 106817                           124             R$/m3                3.111
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 2501                    0.148                 1.589  ...
# 2528                    0.149                 1.779  ...
# 2555                    0.138                 1.799  ...
# 2582                    0.146                 1.760  ...
# 2609                    0.143                 1.789  ...
# ...                       ...                   ...  ...
# 106718                  0.166                 3.179  ...
# 106745                  0.187                 3.279  ...
# 106772                  0.165                 4.599  ...
# 106799                  5.812                50.000  ...
# 106817                  0.260                 2.799  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 2501                       1.806                       0.11
# 2528                       1.839                      0.117
# 2555                       1.895                      0.134
# 2582                       1.935                       0.14
# 2609                       1.963                      0.133
# ...                          ...                        ...
# 106718                     3.102                      0.119
# 106745                     3.197                      0.127
# 106772                      4.39                      0.097
# 106799                    47.535                      3.934
# 106817                     2.404                      0.174
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 2501                         1.31                    2.1358
# 2528                        1.438                    2.2801
# 2555                         1.43                    2.3454
# 2582                        1.438                    2.2925
# 2609                        1.438                    2.2513
# ...                           ...                       ...
# 106718                      2.886                    3.5162
# 106745                     2.9772                    3.5388
# 106772                        4.2                     4.618
# 106799                         39                      58.2
# 106817                      2.126                    2.7909
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 2501                           0.061   2  2006          DEFAULT
# 2528                           0.064   3  2006          DEFAULT
# 2555                           0.071   3  2006          DEFAULT
# 2582                           0.072   3  2006          DEFAULT
# 2609                           0.068   3  2006          DEFAULT
# ...                              ...  ..   ...              ...
# 106718                         0.038   6  2019          DEFAULT
# 106745                          0.04   6  2019          DEFAULT
# 106772                         0.022   6  2019          DEFAULT
# 106799                         0.083   6  2019          DEFAULT
# 106817                         0.072   6  2019          DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 2501                        2501                         12.168
# 2528                        2528                         12.750
# 2555                        2555                         12.978
# 2582                        2582                         12.996
# 2609                        2609                         13.032
# ...                          ...                            ...
# 106718                    106718                         21.414
# 106745                    106745                         22.182
# 106772                    106772                         29.568
# 106799                    106799                        390.060
# 106817                    106817                         18.666
#
# [3054 rows x 23 columns]

# %% [markdown]
# #### **Selecionando registros de postos de São Paulo ou do Rio de Janeiro com Gasolina Comum acima de 2 reais**

# %% [markdown]
# Podemos fazer a solução do "jeito mais lento", percorrendo o DataFrame inteiro _múltiplas vezes_:

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                         0.133   5  2004          DEFAULT
# 1                         0.115   5  2004          DEFAULT
# 2                         0.098   5  2004          DEFAULT
# 3                         0.143   5  2004          DEFAULT
# 4                         0.082   5  2004          DEFAULT
#
#    coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                         0                          7.728
# 1                         1                          6.972
# 2                         2                          8.334
# 3                         3                          7.572
# 4                         4                          7.086
#
# [5 rows x 23 columns]

# %%
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
selecao_1
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
data['PRODUTO'].unique()
# Out:
# array(['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL',
#        'ÓLEO DIESEL S10'], dtype=object)

# %%
selecao_2 = (data['PRODUTO'] == 'GASOLINA COMUM')
selecao_3 = (data['PREÇO MÉDIO REVENDA'] > 2.0)
selecao_final = selecao_1 & selecao_2 & selecao_3

# %%
selecao_final
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %%
data_filtrado = data[selecao_final]
data_filtrado
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12113                           1055              R$/l                2.040
# 12140                           1091              R$/l                2.042
# 12167                           1055              R$/l                2.053
# 12194                           1091              R$/l                2.063
# ...                              ...               ...                  ...
# 106479                          1643              R$/l                4.210
# 106623                           418              R$/l                4.927
# 106629                          1635              R$/l                4.168
# 106772                           422              R$/l                4.928
# 106778                          1644              R$/l                4.142
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 12086                   0.109                 1.700  ...
# 12113                   0.113                 1.700  ...
# 12140                   0.108                 1.700  ...
# 12167                   0.111                 1.730  ...
# 12194                   0.107                 1.760  ...
# ...                       ...                   ...  ...
# 106479                  0.177                 3.759  ...
# 106623                  0.160                 4.599  ...
# 106629                  0.177                 3.679  ...
# 106772                  0.165                 4.599  ...
# 106778                  0.183                 3.769  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12086                      1.791                      0.047
# 12113                      1.788                      0.049
# 12140                       1.79                      0.046
# 12167                      1.802                      0.055
# 12194                      1.816                      0.054
# ...                          ...                        ...
# 106479                     3.785                      0.096
# 106623                     4.383                        0.1
# 106629                     3.725                      0.096
# 106772                      4.39                      0.097
# 106778                     3.713                      0.097
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12086                      1.6363                    1.9594
# 12113                      1.5943                   1.99651
# 12140                     1.63596                    2.2137
# 12167                        1.64                   2.21425
# 12194                        1.64                   2.32425
# ...                           ...                       ...
# 106479                       3.52                    4.1007
# 106623                     4.1972                    4.6239
# 106629                      3.502                    4.0892
# 106772                        4.2                     4.618
# 106778                       3.52                    4.0892
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 12086                          0.026   5  2004          DEFAULT
# 12113                          0.027   5  2004          DEFAULT
# 12140                          0.026   5  2004          DEFAULT
# 12167                          0.031   5  2004          DEFAULT
# 12194                           0.03   6  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106479                         0.025   6  2019          DEFAULT
# 106623                         0.023   6  2019          DEFAULT
# 106629                         0.026   6  2019          DEFAULT
# 106772                         0.022   6  2019          DEFAULT
# 106778                         0.026   6  2019          DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 12086                      12086                         12.270
# 12113                      12113                         12.240
# 12140                      12140                         12.252
# 12167                      12167                         12.318
# 12194                      12194                         12.378
# ...                          ...                            ...
# 106479                    106479                         25.260
# 106623                    106623                         29.562
# 106629                    106629                         25.008
# 106772                    106772                         29.568
# 106778                    106778                         24.852
#
# [1564 rows x 23 columns]

# %%
print(data_filtrado['ESTADO'].unique())
print(data_filtrado['PRODUTO'].unique())
# Out:
# ['RIO DE JANEIRO' 'SAO PAULO']
# ['GASOLINA COMUM']

# %% [markdown]
# <br/>
#
# Alternativamente:

# %%
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
postos_sp_rj = data[selecao_1]

# Apenas registros de postos dos estados de são paulo e rio de janeiro
postos_sp_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 23       2004-05-09  2004-05-15  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106805   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
# 106821   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 22                               952              R$/l                1.098
# 23                              4047              R$/l                0.768
# 49                               948              R$/l                1.092
# 50                              4066              R$/l                0.766
# 76                               973              R$/l                1.103
# ...                              ...               ...                  ...
# 106778                          1644              R$/l                4.142
# 106799                           221           R$/13Kg               65.010
# 106805                          1017           R$/13Kg               66.893
# 106817                           124             R$/m3                3.111
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 22                      0.154                 0.740  ...
# 23                      0.085                 0.590  ...
# 49                      0.157                 0.740  ...
# 50                      0.083                 0.590  ...
# 76                      0.140                 0.770  ...
# ...                       ...                   ...  ...
# 106778                  0.183                 3.769  ...
# 106799                  5.812                50.000  ...
# 106805                  6.100                50.000  ...
# 106817                  0.260                 2.799  ...
# 106821                  0.229                 2.699  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 22                         0.786                      0.173
# 23                          0.57                      0.056
# 49                         0.808                      0.175
# 50                         0.576                       0.05
# 76                         0.822                      0.166
# ...                          ...                        ...
# 106778                     3.713                      0.097
# 106799                    47.535                      3.934
# 106805                    49.214                      5.071
# 106817                     2.404                      0.174
# 106821                     2.374                      0.165
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 22                          0.326                     1.263
# 23                         0.4271                    1.4123
# 49                         0.3257                    1.2921
# 50                        0.43204                    0.9724
# 76                        0.38909                    1.1859
# ...                           ...                       ...
# 106778                       3.52                    4.0892
# 106799                         39                      58.2
# 106805                      40.19                        72
# 106817                      2.126                    2.7909
# 106821                     2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 22                              0.22   5  2004          DEFAULT
# 23                             0.098   5  2004          DEFAULT
# 49                             0.217   5  2004          DEFAULT
# 50                             0.087   5  2004          DEFAULT
# 76                             0.202   5  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106778                         0.026   6  2019          DEFAULT
# 106799                         0.083   6  2019          DEFAULT
# 106805                         0.103   6  2019          DEFAULT
# 106817                         0.072   6  2019          DEFAULT
# 106821                          0.07   6  2019          DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 22                            22                          6.588
# 23                            23                          4.608
# 49                            49                          6.552
# 50                            50                          4.596
# 76                            76                          6.618
# ...                          ...                            ...
# 106778                    106778                         24.852
# 106799                    106799                        390.060
# 106805                    106805                        401.358
# 106817                    106817                         18.666
# 106821                    106821                         18.120
#
# [8526 rows x 23 columns]

# %%
selecao_2 = postos_sp_rj['PRODUTO'] == 'GASOLINA COMUM'
postos_sp_rj_gasolina = postos_sp_rj[selecao_2]

# Apenas registros de postos dos estados de são paulo e rio de janeiro cujo produto é gasolina comum
postos_sp_rj_gasolina
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12087    2004-05-09  2004-05-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12114    2004-05-16  2004-05-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12087                           4107              R$/l                1.891
# 12113                           1055              R$/l                2.040
# 12114                           4133              R$/l                1.888
# 12140                           1091              R$/l                2.042
# ...                              ...               ...                  ...
# 106479                          1643              R$/l                4.210
# 106623                           418              R$/l                4.927
# 106629                          1635              R$/l                4.168
# 106772                           422              R$/l                4.928
# 106778                          1644              R$/l                4.142
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 12086                   0.109                 1.700  ...
# 12087                   0.101                 1.570  ...
# 12113                   0.113                 1.700  ...
# 12114                   0.101                 1.540  ...
# 12140                   0.108                 1.700  ...
# ...                       ...                   ...  ...
# 106479                  0.177                 3.759  ...
# 106623                  0.160                 4.599  ...
# 106629                  0.177                 3.679  ...
# 106772                  0.165                 4.599  ...
# 106778                  0.183                 3.769  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12086                      1.791                      0.047
# 12087                      1.656                      0.064
# 12113                      1.788                      0.049
# 12114                      1.655                      0.063
# 12140                       1.79                      0.046
# ...                          ...                        ...
# 106479                     3.785                      0.096
# 106623                     4.383                        0.1
# 106629                     3.725                      0.096
# 106772                      4.39                      0.097
# 106778                     3.713                      0.097
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12086                      1.6363                    1.9594
# 12087                        1.38                     1.944
# 12113                      1.5943                   1.99651
# 12114                        1.38                    1.9319
# 12140                     1.63596                    2.2137
# ...                           ...                       ...
# 106479                       3.52                    4.1007
# 106623                     4.1972                    4.6239
# 106629                      3.502                    4.0892
# 106772                        4.2                     4.618
# 106778                       3.52                    4.0892
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 12086                          0.026   5  2004          DEFAULT
# 12087                          0.039   5  2004          DEFAULT
# 12113                          0.027   5  2004          DEFAULT
# 12114                          0.038   5  2004          DEFAULT
# 12140                          0.026   5  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106479                         0.025   6  2019          DEFAULT
# 106623                         0.023   6  2019          DEFAULT
# 106629                         0.026   6  2019          DEFAULT
# 106772                         0.022   6  2019          DEFAULT
# 106778                         0.026   6  2019          DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 12086                      12086                         12.270
# 12087                      12087                         11.346
# 12113                      12113                         12.240
# 12114                      12114                         11.328
# 12140                      12140                         12.252
# ...                          ...                            ...
# 106479                    106479                         25.260
# 106623                    106623                         29.562
# 106629                    106629                         25.008
# 106772                    106772                         29.568
# 106778                    106778                         24.852
#
# [1570 rows x 23 columns]

# %%
selecao_3 = postos_sp_rj_gasolina['PREÇO MÉDIO REVENDA'] > 2.0
postos_sp_rj_preco_maior_que_2 = postos_sp_rj_gasolina[selecao_3]

# Apenas registros de postos dos estados de são paulo e rio de janeiro
postos_sp_rj_preco_maior_que_2
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12167    2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12194    2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12086                           1071              R$/l                2.045
# 12113                           1055              R$/l                2.040
# 12140                           1091              R$/l                2.042
# 12167                           1055              R$/l                2.053
# 12194                           1091              R$/l                2.063
# ...                              ...               ...                  ...
# 106479                          1643              R$/l                4.210
# 106623                           418              R$/l                4.927
# 106629                          1635              R$/l                4.168
# 106772                           422              R$/l                4.928
# 106778                          1644              R$/l                4.142
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 12086                   0.109                 1.700  ...
# 12113                   0.113                 1.700  ...
# 12140                   0.108                 1.700  ...
# 12167                   0.111                 1.730  ...
# 12194                   0.107                 1.760  ...
# ...                       ...                   ...  ...
# 106479                  0.177                 3.759  ...
# 106623                  0.160                 4.599  ...
# 106629                  0.177                 3.679  ...
# 106772                  0.165                 4.599  ...
# 106778                  0.183                 3.769  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 12086                      1.791                      0.047
# 12113                      1.788                      0.049
# 12140                       1.79                      0.046
# 12167                      1.802                      0.055
# 12194                      1.816                      0.054
# ...                          ...                        ...
# 106479                     3.785                      0.096
# 106623                     4.383                        0.1
# 106629                     3.725                      0.096
# 106772                      4.39                      0.097
# 106778                     3.713                      0.097
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 12086                      1.6363                    1.9594
# 12113                      1.5943                   1.99651
# 12140                     1.63596                    2.2137
# 12167                        1.64                   2.21425
# 12194                        1.64                   2.32425
# ...                           ...                       ...
# 106479                       3.52                    4.1007
# 106623                     4.1972                    4.6239
# 106629                      3.502                    4.0892
# 106772                        4.2                     4.618
# 106778                       3.52                    4.0892
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 12086                          0.026   5  2004          DEFAULT
# 12113                          0.027   5  2004          DEFAULT
# 12140                          0.026   5  2004          DEFAULT
# 12167                          0.031   5  2004          DEFAULT
# 12194                           0.03   6  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106479                         0.025   6  2019          DEFAULT
# 106623                         0.023   6  2019          DEFAULT
# 106629                         0.026   6  2019          DEFAULT
# 106772                         0.022   6  2019          DEFAULT
# 106778                         0.026   6  2019          DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 12086                      12086                         12.270
# 12113                      12113                         12.240
# 12140                      12140                         12.252
# 12167                      12167                         12.318
# 12194                      12194                         12.378
# ...                          ...                            ...
# 106479                    106479                         25.260
# 106623                    106623                         29.562
# 106629                    106629                         25.008
# 106772                    106772                         29.568
# 106778                    106778                         24.852
#
# [1564 rows x 23 columns]

# %% [markdown]
# #### **Selecionando registros dos anos de 2008, 2010 e 2012**

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                         0.133   5  2004          DEFAULT
# 1                         0.115   5  2004          DEFAULT
# 2                         0.098   5  2004          DEFAULT
# 3                         0.143   5  2004          DEFAULT
# 4                         0.082   5  2004          DEFAULT
#
#    coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                         0                          7.728
# 1                         1                          6.972
# 2                         2                          8.334
# 3                         3                          7.572
# 4                         4                          7.086
#
# [5 rows x 23 columns]

# %% [markdown]
# **ALTERNATIVA 1**

# %%
selecao_4 = (data['ANO'] == 2008) | (data['ANO'] == 2010) | (data['ANO'] == 2012)
selecao_4
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ANO, Length: 106823, dtype: bool

# %%
data[selecao_4]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# 5099   ETANOL HIDRATADO                           255              R$/l
# 5100   ETANOL HIDRATADO                           142              R$/l
# 5101   ETANOL HIDRATADO                           133              R$/l
# 5102   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 55754               GNV                            17             R$/m3
# 55755               GNV                            34             R$/m3
# 55756               GNV                            41             R$/m3
# 55757               GNV                            82             R$/m3
# 55758               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 5098                 1.806                  0.082                 1.709  ...
# 5099                 1.616                  0.100                 1.470  ...
# 5100                 1.581                  0.095                 1.390  ...
# 5101                 1.831                  0.046                 1.680  ...
# 5102                 1.699                  0.098                 1.530  ...
# ...                    ...                    ...                   ...  ...
# 55754                1.891                  0.015                 1.860  ...
# 55755                1.980                  0.040                 1.919  ...
# 55756                2.003                  0.034                 1.879  ...
# 55757                1.598                  0.199                 1.399  ...
# 55758                1.847                  0.033                 1.790  ...
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 5098                      1.516                      0.061
# 5099                      1.323                       0.05
# 5100                      1.303                      0.073
# 5101                      1.449                      0.044
# 5102                        1.5                      0.062
# ...                         ...                        ...
# 55754                     1.425                      0.098
# 55755                     1.414                      0.028
# 55756                         -                          -
# 55757                     1.201                      0.182
# 55758                     1.343                      0.178
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 5098                      1.3892                    1.6157
# 5099                      1.2242                    1.6173
# 5100                        1.14                      1.45
# 5101                      1.3247                    1.5514
# 5102                        1.39                    1.7689
# ...                          ...                       ...
# 55754                     1.2657                    1.4789
# 55755                     1.3997                    1.4608
# 55756                          -                         -
# 55757                     0.8354                     1.535
# 55758                     1.1253                     1.543
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 5098                           0.04   1  2008          DEFAULT
# 5099                          0.038   1  2008          DEFAULT
# 5100                          0.056   1  2008          DEFAULT
# 5101                           0.03   1  2008          DEFAULT
# 5102                          0.041   1  2008          DEFAULT
# ...                             ...  ..   ...              ...
# 55754                         0.069  12  2012          DEFAULT
# 55755                          0.02  12  2012          DEFAULT
# 55756                             -  12  2012          DEFAULT
# 55757                         0.152  12  2012          DEFAULT
# 55758                         0.133  12  2012          DEFAULT
#
#        coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 5098                       5098                         10.836
# 5099                       5099                          9.696
# 5100                       5100                          9.486
# 5101                       5101                         10.986
# 5102                       5102                         10.194
# ...                         ...                            ...
# 55754                     55754                         11.346
# 55755                     55755                         11.880
# 55756                     55756                         12.018
# 55757                     55757                          9.588
# 55758                     55758                         11.082
#
# [19576 rows x 23 columns]

# %%
data[selecao_4]['ANO']
# Out:
# 5098     2008
# 5099     2008
# 5100     2008
# 5101     2008
# 5102     2008
#          ...
# 55754    2012
# 55755    2012
# 55756    2012
# 55757    2012
# 55758    2012
# Name: ANO, Length: 19576, dtype: int64

# %%
data[selecao_4]['ANO'].unique()
# Out:
# array([2008, 2010, 2012], dtype=int64)

# %% [markdown]
# **ALTERNATIVA 2**

# %%
# Criando uma lista com os anos requeridos para busca
lista_de_anos = [2008, 2010, 2012]

# %%
selecao_5 = data['ANO'].isin(lista_de_anos) # Retorna uma Series de booleanos
selecao_5
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ANO, Length: 106823, dtype: bool

# %%
data[selecao_5]
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# 5099   ETANOL HIDRATADO                           255              R$/l
# 5100   ETANOL HIDRATADO                           142              R$/l
# 5101   ETANOL HIDRATADO                           133              R$/l
# 5102   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 55754               GNV                            17             R$/m3
# 55755               GNV                            34             R$/m3
# 55756               GNV                            41             R$/m3
# 55757               GNV                            82             R$/m3
# 55758               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 5098                 1.806                  0.082                 1.709  ...
# 5099                 1.616                  0.100                 1.470  ...
# 5100                 1.581                  0.095                 1.390  ...
# 5101                 1.831                  0.046                 1.680  ...
# 5102                 1.699                  0.098                 1.530  ...
# ...                    ...                    ...                   ...  ...
# 55754                1.891                  0.015                 1.860  ...
# 55755                1.980                  0.040                 1.919  ...
# 55756                2.003                  0.034                 1.879  ...
# 55757                1.598                  0.199                 1.399  ...
# 55758                1.847                  0.033                 1.790  ...
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 5098                      1.516                      0.061
# 5099                      1.323                       0.05
# 5100                      1.303                      0.073
# 5101                      1.449                      0.044
# 5102                        1.5                      0.062
# ...                         ...                        ...
# 55754                     1.425                      0.098
# 55755                     1.414                      0.028
# 55756                         -                          -
# 55757                     1.201                      0.182
# 55758                     1.343                      0.178
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 5098                      1.3892                    1.6157
# 5099                      1.2242                    1.6173
# 5100                        1.14                      1.45
# 5101                      1.3247                    1.5514
# 5102                        1.39                    1.7689
# ...                          ...                       ...
# 55754                     1.2657                    1.4789
# 55755                     1.3997                    1.4608
# 55756                          -                         -
# 55757                     0.8354                     1.535
# 55758                     1.1253                     1.543
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 5098                           0.04   1  2008          DEFAULT
# 5099                          0.038   1  2008          DEFAULT
# 5100                          0.056   1  2008          DEFAULT
# 5101                           0.03   1  2008          DEFAULT
# 5102                          0.041   1  2008          DEFAULT
# ...                             ...  ..   ...              ...
# 55754                         0.069  12  2012          DEFAULT
# 55755                          0.02  12  2012          DEFAULT
# 55756                             -  12  2012          DEFAULT
# 55757                         0.152  12  2012          DEFAULT
# 55758                         0.133  12  2012          DEFAULT
#
#        coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 5098                       5098                         10.836
# 5099                       5099                          9.696
# 5100                       5100                          9.486
# 5101                       5101                         10.986
# 5102                       5102                         10.194
# ...                         ...                            ...
# 55754                     55754                         11.346
# 55755                     55755                         11.880
# 55756                     55756                         12.018
# 55757                     55757                          9.588
# 55758                     55758                         11.082
#
# [19576 rows x 23 columns]

# %% [markdown]
# **ALTERNATIVA 3**

# %%
# Usando o método query em cima da lista criada
lista_de_anos
# Out:
# [2008, 2010, 2012]

# %%
selecao_6 = data.query('ANO in @lista_de_anos')
selecao_6
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 55754   2012-12-30  2013-01-05      NORDESTE  RIO GRANDE DO NORTE
# 55755   2012-12-30  2013-01-05           SUL    RIO GRANDE DO SUL
# 55756   2012-12-30  2013-01-05           SUL       SANTA CATARINA
# 55757   2012-12-30  2013-01-05       SUDESTE            SAO PAULO
# 55758   2012-12-30  2013-01-05      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# 5099   ETANOL HIDRATADO                           255              R$/l
# 5100   ETANOL HIDRATADO                           142              R$/l
# 5101   ETANOL HIDRATADO                           133              R$/l
# 5102   ETANOL HIDRATADO                            97              R$/l
# ...                 ...                           ...               ...
# 55754               GNV                            17             R$/m3
# 55755               GNV                            34             R$/m3
# 55756               GNV                            41             R$/m3
# 55757               GNV                            82             R$/m3
# 55758               GNV                            11             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 5098                 1.806                  0.082                 1.709  ...
# 5099                 1.616                  0.100                 1.470  ...
# 5100                 1.581                  0.095                 1.390  ...
# 5101                 1.831                  0.046                 1.680  ...
# 5102                 1.699                  0.098                 1.530  ...
# ...                    ...                    ...                   ...  ...
# 55754                1.891                  0.015                 1.860  ...
# 55755                1.980                  0.040                 1.919  ...
# 55756                2.003                  0.034                 1.879  ...
# 55757                1.598                  0.199                 1.399  ...
# 55758                1.847                  0.033                 1.790  ...
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 5098                      1.516                      0.061
# 5099                      1.323                       0.05
# 5100                      1.303                      0.073
# 5101                      1.449                      0.044
# 5102                        1.5                      0.062
# ...                         ...                        ...
# 55754                     1.425                      0.098
# 55755                     1.414                      0.028
# 55756                         -                          -
# 55757                     1.201                      0.182
# 55758                     1.343                      0.178
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 5098                      1.3892                    1.6157
# 5099                      1.2242                    1.6173
# 5100                        1.14                      1.45
# 5101                      1.3247                    1.5514
# 5102                        1.39                    1.7689
# ...                          ...                       ...
# 55754                     1.2657                    1.4789
# 55755                     1.3997                    1.4608
# 55756                          -                         -
# 55757                     0.8354                     1.535
# 55758                     1.1253                     1.543
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 5098                           0.04   1  2008          DEFAULT
# 5099                          0.038   1  2008          DEFAULT
# 5100                          0.056   1  2008          DEFAULT
# 5101                           0.03   1  2008          DEFAULT
# 5102                          0.041   1  2008          DEFAULT
# ...                             ...  ..   ...              ...
# 55754                         0.069  12  2012          DEFAULT
# 55755                          0.02  12  2012          DEFAULT
# 55756                             -  12  2012          DEFAULT
# 55757                         0.152  12  2012          DEFAULT
# 55758                         0.133  12  2012          DEFAULT
#
#        coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 5098                       5098                         10.836
# 5099                       5099                          9.696
# 5100                       5100                          9.486
# 5101                       5101                         10.986
# 5102                       5102                         10.194
# ...                         ...                            ...
# 55754                     55754                         11.346
# 55755                     55755                         11.880
# 55756                     55756                         12.018
# 55757                     55757                          9.588
# 55758                     55758                         11.082
#
# [19576 rows x 23 columns]

# %% [markdown]
# ### **Iterando com DataFrames**

# %% [markdown]
# #### For-each `DataFrame.iterrows()` (LENTO ==> apenas indicado para iterar pequenos conjunto de dados)

# %%
data.head(10)
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6   2004-05-09  2004-05-15      NORDESTE               CEARA
# 7   2004-05-09  2004-05-15      NORDESTE            MARANHAO
# 8   2004-05-09  2004-05-15      NORDESTE             PARAIBA
# 9   2004-05-09  2004-05-15      NORDESTE          PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
# 6  ETANOL HIDRATADO                           278              R$/l
# 7  ETANOL HIDRATADO                           105              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                 1.190  ...
# 1                1.162                  0.114                 0.890  ...
# 2                1.389                  0.097                 1.180  ...
# 3                1.262                  0.070                 1.090  ...
# 4                1.181                  0.078                 1.050  ...
# 5                1.383                  0.132                 0.999  ...
# 6                1.453                  0.218                 1.030  ...
# 7                1.631                  0.158                 1.350  ...
# 8                1.284                  0.130                 1.100  ...
# 9                1.224                  0.141                 0.989  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
# 5                     0.957                      0.128
# 6                       1.1                      0.068
# 7                     1.116                      0.091
# 8                     0.931                      0.072
# 9                     0.947                      0.091
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
# 5                     0.5686                      1.35
# 6                     0.7332                     1.294
# 7                     0.9923                   1.36183
# 8                     0.7577                    1.2972
# 9                     0.5643                    1.3541
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                         0.133   5  2004          DEFAULT
# 1                         0.115   5  2004          DEFAULT
# 2                         0.098   5  2004          DEFAULT
# 3                         0.143   5  2004          DEFAULT
# 4                         0.082   5  2004          DEFAULT
# 5                         0.134   5  2004          DEFAULT
# 6                         0.062   5  2004          DEFAULT
# 7                         0.082   5  2004          DEFAULT
# 8                         0.077   5  2004          DEFAULT
# 9                         0.096   5  2004          DEFAULT
#
#    coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                         0                          7.728
# 1                         1                          6.972
# 2                         2                          8.334
# 3                         3                          7.572
# 4                         4                          7.086
# 5                         5                          8.298
# 6                         6                          8.718
# 7                         7                          9.786
# 8                         8                          7.704
# 9                         9                          7.344
#
# [10 rows x 23 columns]

# %%
for index, row in data.head(10).iterrows():
    print(f'índice {index} ==> {row["ESTADO"]}')
# Out:
# índice 0 ==> DISTRITO FEDERAL
# índice 1 ==> GOIAS
# índice 2 ==> MATO GROSSO
# índice 3 ==> MATO GROSSO DO SUL
# índice 4 ==> ALAGOAS
# índice 5 ==> BAHIA
# índice 6 ==> CEARA
# índice 7 ==> MARANHAO
# índice 8 ==> PARAIBA
# índice 9 ==> PERNAMBUCO

# %% [markdown]
# <h2>2. Preparação dos dados</h2>
# <hr/>

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 106818                3.574                  0.065                 3.499  ...
# 106819                3.401                  0.129                 3.230  ...
# 106820                2.912                  0.190                 2.699  ...
# 106821                3.020                  0.229                 2.699  ...
# 106822                3.697                  0.005                 3.689  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.9666
# 1                          0.5013                      1.05
# 2                          0.5614                     1.161
# 3                          0.5991                   1.22242
# 4                          0.7441                    1.0317
# ...                           ...                       ...
# 106818                      2.756                     2.756
# 106819                     1.9842                    2.8661
# 106820                     1.9981                    1.9981
# 106821                     2.0179                    2.5093
# 106822                     2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 0                              0.133   5  2004          DEFAULT
# 1                              0.115   5  2004          DEFAULT
# 2                              0.098   5  2004          DEFAULT
# 3                              0.143   5  2004          DEFAULT
# 4                              0.082   5  2004          DEFAULT
# ...                              ...  ..   ...              ...
# 106818                             0   6  2019          DEFAULT
# 106819                         0.164   6  2019          DEFAULT
# 106820                             0   6  2019          DEFAULT
# 106821                          0.07   6  2019          DEFAULT
# 106822                             0   6  2019          DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                              0                          7.728
# 1                              1                          6.972
# 2                              2                          8.334
# 3                              3                          7.572
# 4                              4                          7.086
# ...                          ...                            ...
# 106818                    106818                         21.444
# 106819                    106819                         20.406
# 106820                    106820                         17.472
# 106821                    106821                         18.120
# 106822                    106822                         22.182
#
# [106823 rows x 23 columns]

# %% [markdown]
# ### 2.1 Removendo amostras com valores vazios (null / nan) no dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  object
#  1   DATA FINAL                     106823 non-null  object
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
#  20  coluna sem nocao               106823 non-null  object
#  21  coluna a partir de lista       106823 non-null  int64
#  22  PREÇO MÉDIO REVENDA (dólares)  106823 non-null  float64
# dtypes: float64(6), int64(4), object(13)
# memory usage: 18.7+ MB

# %% [markdown]
# De um total de 106823 observações, **não há valores null** / nan para nenhum atributo. Mas, veremos que não é bem assim neste caso específico.<br/><br/>

# %% [markdown]
# ### 2.2 Conversão de tipos de atributos

# %% [markdown]
# O pandas automaticamente reconhece os tipos de dados de cada coluna. <br/>
# Porém, existem alguns atributos que estão com seus tipos errados: P. ex., "PREÇO MÉDIO DISTRIBUIÇÃO" deveria ser ```float64``` e não ```object```.<br/>
# Nestes casos, muito provavelmente algumas amostras têm um string ao invés de um número para tais atributos. <br/>
#
# Os atributos *"DATA INICIAL"* e *"DATA FINAL"* deveriam ser do tipo `datetime`.
#
# Em outros casos, alguns **atributos categóricos** são ```objects```, mas poderiam ter o tipo ```category```, que é um tipo especial do pandas. <br/>
# Este tipo é necessário para se utilizar algumas funções específicas do pandas. <br/>
# **Não** converteremos para este tipo por ora.

# %%
# Criando uma cópia para não modificar o dataframe original
data_pre = data.copy()

# %% [markdown]
# #### **Datas**
# Como os atributos de data do datset já estão em um formato de data aceitável (YYYY-MM-DD), não precisamos forçar nenhuma conversão nesse sentido.

# %%
data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
#  20  coluna sem nocao               106823 non-null  object
#  21  coluna a partir de lista       106823 non-null  int64
#  22  PREÇO MÉDIO REVENDA (dólares)  106823 non-null  float64
# dtypes: datetime64[ns](2), float64(6), int64(4), object(11)
# memory usage: 18.7+ MB

# %% [markdown]
# #### **Dados Numéricos**

# %%
# Convertendo atributos/colunas para 'numeric'
lista = ['MARGEM MÉDIA REVENDA', 
         'PREÇO MÉDIO DISTRIBUIÇÃO', 
         'DESVIO PADRÃO DISTRIBUIÇÃO', 
         'PREÇO MÍNIMO DISTRIBUIÇÃO', 
         'PREÇO MÍNIMO DISTRIBUIÇÃO', 
         'PREÇO MÁXIMO DISTRIBUIÇÃO', 
         'COEF DE VARIAÇÃO DISTRIBUIÇÃO'
]

for atributo in lista:
    # converte a coluna [de valores string] para um tipo numérico
    # Em caso de erro na conversão (p.ex.: uma string que não representa um número), um valor vazior (null/nan) será exibido no lugar
    data_pre[atributo] = pd.to_numeric(data_pre[atributo], errors='coerce')

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
#  12  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       103423 non-null  float64
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     103423 non-null  float64
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      103423 non-null  float64
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      103423 non-null  float64
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  103423 non-null  float64
#  18  MÊS                            106823 non-null  int64
#  19  ANO                            106823 non-null  int64
#  20  coluna sem nocao               106823 non-null  object
#  21  coluna a partir de lista       106823 non-null  int64
#  22  PREÇO MÉDIO REVENDA (dólares)  106823 non-null  float64
# dtypes: datetime64[ns](2), float64(12), int64(4), object(5)
# memory usage: 18.7+ MB

# %% [markdown]
# <br/>
#
# Note que temos vários valores ***null*** agora **após a *conversão de tipos***. Vamos checá-los com mais cuidado nos dados originais e preprocessados.

# %% [markdown]
# ### 2.3 Limpeza de dados

# %%
mask = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()

# %%
data_pre[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                         NaN                         NaN
# 1958                         NaN                         NaN
# 2012                         NaN                         NaN
# 2497                         NaN                         NaN
# 3199                         NaN                         NaN
# ...                          ...                         ...
# 106664                       NaN                         NaN
# 106666                       NaN                         NaN
# 106811                       NaN                         NaN
# 106813                       NaN                         NaN
# 106815                       NaN                         NaN
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                          NaN                        NaN
# 1958                          NaN                        NaN
# 2012                          NaN                        NaN
# 2497                          NaN                        NaN
# 3199                          NaN                        NaN
# ...                           ...                        ...
# 106664                        NaN                        NaN
# 106666                        NaN                        NaN
# 106811                        NaN                        NaN
# 106813                        NaN                        NaN
# 106815                        NaN                        NaN
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 1903                              NaN    9  2005           DEFAULT
# 1958                              NaN   10  2005           DEFAULT
# 2012                              NaN   10  2005           DEFAULT
# 2497                              NaN    2  2006           DEFAULT
# 3199                              NaN    8  2006           DEFAULT
# ...                               ...  ...   ...               ...
# 106664                            NaN    6  2019           DEFAULT
# 106666                            NaN    6  2019           DEFAULT
# 106811                            NaN    6  2019           DEFAULT
# 106813                            NaN    6  2019           DEFAULT
# 106815                            NaN    6  2019           DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 1903                        1903                         10.164
# 1958                        1958                         12.000
# 2012                        2012                         13.662
# 2497                        2497                         13.092
# 3199                        3199                         13.710
# ...                          ...                            ...
# 106664                    106664                         20.670
# 106666                    106666                         18.792
# 106811                    106811                         19.794
# 106813                    106813                         21.288
# 106815                    106815                         19.740
#
# [3400 rows x 23 columns]

# %%
# Nos dados originais, quais eram os valores do PREÇO MÉDIO DISTRIBUIÇÃO dos registros que agora possuem valore NaN
data[mask]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25  2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09  2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23  2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26  2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27  2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106664   2019-06-16  2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16  2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23  2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23  2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23  2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                           -                          -
# 1958                           -                          -
# 2012                           -                          -
# 2497                           -                          -
# 3199                           -                          -
# ...                          ...                        ...
# 106664                         -                          -
# 106666                         -                          -
# 106811                         -                          -
# 106813                         -                          -
# 106815                         -                          -
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                            -                         -
# 1958                            -                         -
# 2012                            -                         -
# 2497                            -                         -
# 3199                            -                         -
# ...                           ...                       ...
# 106664                          -                         -
# 106666                          -                         -
# 106811                          -                         -
# 106813                          -                         -
# 106815                          -                         -
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO coluna sem nocao  \
# 1903                               -   9  2005          DEFAULT
# 1958                               -  10  2005          DEFAULT
# 2012                               -  10  2005          DEFAULT
# 2497                               -   2  2006          DEFAULT
# 3199                               -   8  2006          DEFAULT
# ...                              ...  ..   ...              ...
# 106664                             -   6  2019          DEFAULT
# 106666                             -   6  2019          DEFAULT
# 106811                             -   6  2019          DEFAULT
# 106813                             -   6  2019          DEFAULT
# 106815                             -   6  2019          DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 1903                        1903                         10.164
# 1958                        1958                         12.000
# 2012                        2012                         13.662
# 2497                        2497                         13.092
# 3199                        3199                         13.710
# ...                          ...                            ...
# 106664                    106664                         20.670
# 106666                    106666                         18.792
# 106811                    106811                         19.794
# 106813                    106813                         21.288
# 106815                    106815                         19.740
#
# [3400 rows x 23 columns]

# %% [markdown]
# Várias amostras possuem a _string '-'_ em algumas colunas ao invés de um número de fato. Ou seja, não há aferições destes atributos para estas amostras. <br/>
#
# <br/>
#
# Poderíamos **preencher os valores NaN com um valor padrão**. Para isso, basta usar o método `.fillna`.

# %%
# Retorna uma cópia do dataframe 'data_pre' com todos os valores NaN de todas as colunas agora preenchidos com 0. 
# Para alterar o próprio dataframe, use o argumento 'inplace=True'ArithmeticError
data_pre_fill = data_pre.fillna(0)
data_pre_fill
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09 2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09 2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09 2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09 2004-05-15      NORDESTE              ALAGOAS
# ...             ...        ...           ...                  ...
# 106818   2019-06-23 2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23 2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23 2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23 2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23 2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 106818                3.574                  0.065                 3.499  ...
# 106819                3.401                  0.129                 3.230  ...
# 106820                2.912                  0.190                 2.699  ...
# 106821                3.020                  0.229                 2.699  ...
# 106822                3.697                  0.005                 3.689  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                       0.000
# 106819                     2.451                       0.402
# 106820                     1.998                       0.000
# 106821                     2.374                       0.165
# 106822                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 106818                     2.7560                    2.75600
# 106819                     1.9842                    2.86610
# 106820                     1.9981                    1.99810
# 106821                     2.0179                    2.50930
# 106822                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 0                               0.133    5  2004           DEFAULT
# 1                               0.115    5  2004           DEFAULT
# 2                               0.098    5  2004           DEFAULT
# 3                               0.143    5  2004           DEFAULT
# 4                               0.082    5  2004           DEFAULT
# ...                               ...  ...   ...               ...
# 106818                          0.000    6  2019           DEFAULT
# 106819                          0.164    6  2019           DEFAULT
# 106820                          0.000    6  2019           DEFAULT
# 106821                          0.070    6  2019           DEFAULT
# 106822                          0.000    6  2019           DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                              0                          7.728
# 1                              1                          6.972
# 2                              2                          8.334
# 3                              3                          7.572
# 4                              4                          7.086
# ...                          ...                            ...
# 106818                    106818                         21.444
# 106819                    106819                         20.406
# 106820                    106820                         17.472
# 106821                    106821                         18.120
# 106822                    106822                         22.182
#
# [106823 rows x 23 columns]

# %%
data_pre_fill[mask] # Valores que eram NaN agora são 0
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                         0.0                         0.0
# 1958                         0.0                         0.0
# 2012                         0.0                         0.0
# 2497                         0.0                         0.0
# 3199                         0.0                         0.0
# ...                          ...                         ...
# 106664                       0.0                         0.0
# 106666                       0.0                         0.0
# 106811                       0.0                         0.0
# 106813                       0.0                         0.0
# 106815                       0.0                         0.0
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                          0.0                        0.0
# 1958                          0.0                        0.0
# 2012                          0.0                        0.0
# 2497                          0.0                        0.0
# 3199                          0.0                        0.0
# ...                           ...                        ...
# 106664                        0.0                        0.0
# 106666                        0.0                        0.0
# 106811                        0.0                        0.0
# 106813                        0.0                        0.0
# 106815                        0.0                        0.0
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 1903                              0.0    9  2005           DEFAULT
# 1958                              0.0   10  2005           DEFAULT
# 2012                              0.0   10  2005           DEFAULT
# 2497                              0.0    2  2006           DEFAULT
# 3199                              0.0    8  2006           DEFAULT
# ...                               ...  ...   ...               ...
# 106664                            0.0    6  2019           DEFAULT
# 106666                            0.0    6  2019           DEFAULT
# 106811                            0.0    6  2019           DEFAULT
# 106813                            0.0    6  2019           DEFAULT
# 106815                            0.0    6  2019           DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 1903                        1903                         10.164
# 1958                        1958                         12.000
# 2012                        2012                         13.662
# 2497                        2497                         13.092
# 3199                        3199                         13.710
# ...                          ...                            ...
# 106664                    106664                         20.670
# 106666                    106666                         18.792
# 106811                    106811                         19.794
# 106813                    106813                         21.288
# 106815                    106815                         19.740
#
# [3400 rows x 23 columns]

# %%
data_pre[mask] # O dataframe original não foi alterado
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                         NaN                         NaN
# 1958                         NaN                         NaN
# 2012                         NaN                         NaN
# 2497                         NaN                         NaN
# 3199                         NaN                         NaN
# ...                          ...                         ...
# 106664                       NaN                         NaN
# 106666                       NaN                         NaN
# 106811                       NaN                         NaN
# 106813                       NaN                         NaN
# 106815                       NaN                         NaN
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                          NaN                        NaN
# 1958                          NaN                        NaN
# 2012                          NaN                        NaN
# 2497                          NaN                        NaN
# 3199                          NaN                        NaN
# ...                           ...                        ...
# 106664                        NaN                        NaN
# 106666                        NaN                        NaN
# 106811                        NaN                        NaN
# 106813                        NaN                        NaN
# 106815                        NaN                        NaN
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 1903                              NaN    9  2005           DEFAULT
# 1958                              NaN   10  2005           DEFAULT
# 2012                              NaN   10  2005           DEFAULT
# 2497                              NaN    2  2006           DEFAULT
# 3199                              NaN    8  2006           DEFAULT
# ...                               ...  ...   ...               ...
# 106664                            NaN    6  2019           DEFAULT
# 106666                            NaN    6  2019           DEFAULT
# 106811                            NaN    6  2019           DEFAULT
# 106813                            NaN    6  2019           DEFAULT
# 106815                            NaN    6  2019           DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 1903                        1903                         10.164
# 1958                        1958                         12.000
# 2012                        2012                         13.662
# 2497                        2497                         13.092
# 3199                        3199                         13.710
# ...                          ...                            ...
# 106664                    106664                         20.670
# 106666                    106666                         18.792
# 106811                    106811                         19.794
# 106813                    106813                         21.288
# 106815                    106815                         19.740
#
# [3400 rows x 23 columns]

# %%
# Retorna uma cópia do dataframe 'data_pre' com todos os valores NaN de todas as colunas agora preenchidos com 0. 
# Para alterar o próprio dataframe, use o argumento 'inplace=True'ArithmeticError
data_pre_fill = data_pre.fillna(value={
    'PREÇO MÉDIO DISTRIBUIÇÃO': 10,
    'DESVIO PADRÃO DISTRIBUIÇÃO': 20,
    'PREÇO MÍNIMO DISTRIBUIÇÃO': 30,
    'PREÇO MÁXIMO DISTRIBUIÇÃO': 'vazio',
})
data_pre_fill
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09 2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09 2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09 2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09 2004-05-15      NORDESTE              ALAGOAS
# ...             ...        ...           ...                  ...
# 106818   2019-06-23 2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23 2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23 2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23 2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23 2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 106818               GNV                             7             R$/m3
# 106819               GNV                            23             R$/m3
# 106820               GNV                            24             R$/m3
# 106821               GNV                            52             R$/m3
# 106822               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 106818                3.574                  0.065                 3.499  ...
# 106819                3.401                  0.129                 3.230  ...
# 106820                2.912                  0.190                 2.699  ...
# 106821                3.020                  0.229                 2.699  ...
# 106822                3.697                  0.005                 3.689  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                       0.000
# 106819                     2.451                       0.402
# 106820                     1.998                       0.000
# 106821                     2.374                       0.165
# 106822                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                     0.9666
# 1                          0.5013                       1.05
# 2                          0.5614                      1.161
# 3                          0.5991                    1.22242
# 4                          0.7441                     1.0317
# ...                           ...                        ...
# 106818                     2.7560                      2.756
# 106819                     1.9842                     2.8661
# 106820                     1.9981                     1.9981
# 106821                     2.0179                     2.5093
# 106822                     2.5175                     2.5175
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 0                               0.133    5  2004           DEFAULT
# 1                               0.115    5  2004           DEFAULT
# 2                               0.098    5  2004           DEFAULT
# 3                               0.143    5  2004           DEFAULT
# 4                               0.082    5  2004           DEFAULT
# ...                               ...  ...   ...               ...
# 106818                          0.000    6  2019           DEFAULT
# 106819                          0.164    6  2019           DEFAULT
# 106820                          0.000    6  2019           DEFAULT
# 106821                          0.070    6  2019           DEFAULT
# 106822                          0.000    6  2019           DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                              0                          7.728
# 1                              1                          6.972
# 2                              2                          8.334
# 3                              3                          7.572
# 4                              4                          7.086
# ...                          ...                            ...
# 106818                    106818                         21.444
# 106819                    106819                         20.406
# 106820                    106820                         17.472
# 106821                    106821                         18.120
# 106822                    106822                         22.182
#
# [106823 rows x 23 columns]

# %%
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1903                               2              R$/l                1.694
# 1958                               3              R$/l                2.000
# 2012                               3              R$/l                2.277
# 2497                              11              R$/l                2.182
# 3199                              22              R$/l                2.285
# ...                              ...               ...                  ...
# 106664                             5             R$/m3                3.445
# 106666                             7             R$/m3                3.132
# 106811                             4             R$/m3                3.299
# 106813                             6             R$/m3                3.548
# 106815                             1             R$/m3                3.290
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1903                    0.283                 1.690  ...
# 1958                    0.000                 2.000  ...
# 2012                    0.023                 2.250  ...
# 2497                    0.040                 2.100  ...
# 3199                    0.068                 1.980  ...
# ...                       ...                   ...  ...
# 106664                  0.147                 3.347  ...
# 106666                  0.295                 3.049  ...
# 106811                  0.005                 3.290  ...
# 106813                  0.100                 3.495  ...
# 106815                  0.000                 3.290  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1903                        10.0                        20.0
# 1958                        10.0                        20.0
# 2012                        10.0                        20.0
# 2497                        10.0                        20.0
# 3199                        10.0                        20.0
# ...                          ...                         ...
# 106664                      10.0                        20.0
# 106666                      10.0                        20.0
# 106811                      10.0                        20.0
# 106813                      10.0                        20.0
# 106815                      10.0                        20.0
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 1903                         30.0                      vazio
# 1958                         30.0                      vazio
# 2012                         30.0                      vazio
# 2497                         30.0                      vazio
# 3199                         30.0                      vazio
# ...                           ...                        ...
# 106664                       30.0                      vazio
# 106666                       30.0                      vazio
# 106811                       30.0                      vazio
# 106813                       30.0                      vazio
# 106815                       30.0                      vazio
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 1903                              NaN    9  2005           DEFAULT
# 1958                              NaN   10  2005           DEFAULT
# 2012                              NaN   10  2005           DEFAULT
# 2497                              NaN    2  2006           DEFAULT
# 3199                              NaN    8  2006           DEFAULT
# ...                               ...  ...   ...               ...
# 106664                            NaN    6  2019           DEFAULT
# 106666                            NaN    6  2019           DEFAULT
# 106811                            NaN    6  2019           DEFAULT
# 106813                            NaN    6  2019           DEFAULT
# 106815                            NaN    6  2019           DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 1903                        1903                         10.164
# 1958                        1958                         12.000
# 2012                        2012                         13.662
# 2497                        2497                         13.092
# 3199                        3199                         13.710
# ...                          ...                            ...
# 106664                    106664                         20.670
# 106666                    106666                         18.792
# 106811                    106811                         19.794
# 106813                    106813                         21.288
# 106815                    106815                         19.740
#
# [3400 rows x 23 columns]

# %% [markdown]
# <br/>
#
# Por mais que a função `fillna` seja interessante e útil em muitos casos, no problema em questão estamos interessados em analisar precisamente, p. ex., o **'PREÇO MÉDIO DISTRIBUIÇÃO'**.<br/>
#
# A fim de não termos valores _sintéticos_ gerados pelo `fillna`, que possam atrapalhar nossa análise, iremos **remover (drop) todas as amostras que possuem qualquer valor NaN** para quaisquer atributos/colunas. <br/>
#
# Para isso, basta utilizarmos o método `dropna`.

# %%
# Remove, no próprio dataframe, todas as linhas/registros com valores NaN (vazios) em quaisquer colunas/atributos
data_pre.dropna(inplace=True)

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103392 entries, 0 to 106822
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  datetime64[ns]
#  1   DATA FINAL                     103392 non-null  datetime64[ns]
#  2   REGIÃO                         103392 non-null  object
#  3   ESTADO                         103392 non-null  object
#  4   PRODUTO                        103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  6   UNIDADE DE MEDIDA              103392 non-null  object
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
#  12  COEF DE VARIAÇÃO REVENDA       103392 non-null  float64
#  13  PREÇO MÉDIO DISTRIBUIÇÃO       103392 non-null  float64
#  14  DESVIO PADRÃO DISTRIBUIÇÃO     103392 non-null  float64
#  15  PREÇO MÍNIMO DISTRIBUIÇÃO      103392 non-null  float64
#  16  PREÇO MÁXIMO DISTRIBUIÇÃO      103392 non-null  float64
#  17  COEF DE VARIAÇÃO DISTRIBUIÇÃO  103392 non-null  float64
#  18  MÊS                            103392 non-null  int64
#  19  ANO                            103392 non-null  int64
#  20  coluna sem nocao               103392 non-null  object
#  21  coluna a partir de lista       103392 non-null  int64
#  22  PREÇO MÉDIO REVENDA (dólares)  103392 non-null  float64
# dtypes: datetime64[ns](2), float64(12), int64(4), object(5)
# memory usage: 18.9+ MB

# %% [markdown]
# Nosso data frame agora, após essa _limpeza_, ficou mais enxuto, contentdo 103392 registros frente aos 106823 registros originais. <br/>
#
# Essas são apenas algumas das possíveis _técnicas de limpeza de dados_. Outras estratégias, p. ex., **confiam na detecção de outliers**, que não veremos neste curso.

# %% [markdown]
# #### **Salvando o Dataset Preprocessado**

# %%
data_pre.to_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado_final.csv', index=False)

# %% [markdown]
# <h2>3. Estatísticas Descritivas</h2>
# <hr/>

# %% [markdown]
# O Pandas fornecem algumas funções/métodos ue computam certas estatísticas descritivas.

# %% [markdown]
# `describe`: exibe várias **estatísticas descritivas** para os _atributos_ de um dataframe ou para uma _Series_.

# %%
data_final = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019_preprocessado_final.csv')

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.110
# 1                     0.763                       0.088
# 2                     0.970                       0.095
# 3                     0.830                       0.119
# 4                     0.941                       0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.96660
# 1                     0.5013                    1.05000
# 2                     0.5614                    1.16100
# 3                     0.5991                    1.22242
# 4                     0.7441                    1.03170
#
#    COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 0                          0.133    5  2004           DEFAULT
# 1                          0.115    5  2004           DEFAULT
# 2                          0.098    5  2004           DEFAULT
# 3                          0.143    5  2004           DEFAULT
# 4                          0.082    5  2004           DEFAULT
#
#    coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                         0                          7.728
# 1                         1                          6.972
# 2                         2                          8.334
# 3                         3                          7.572
# 4                         4                          7.086
#
# [5 rows x 23 columns]

# %%
stats = data_final.describe()
stats
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# 50%                 0.115000              2.509000              3.000000
# 75%                 0.190000              3.490000              4.150000
# max                10.748000             90.000000            120.000000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         103392.000000             103392.000000
# mean               2.225151                  0.045749
# std                4.375085                  0.024488
# min                0.001000                  0.000000
# 25%                0.282000                  0.030000
# 50%                0.383000                  0.042000
# 75%                0.560000                  0.058000
# max               36.847000                  0.262000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             103392.000000               103392.000000
# mean                   8.559322                    0.559441
# std                   13.603686                    1.256914
# min                    0.506000                    0.000000
# 25%                    1.795000                    0.047000
# 50%                    2.335000                    0.077000
# 75%                    3.307000                    0.151000
# max                   83.137000                   18.385000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              103392.000000              103392.000000
# mean                    7.414814                   9.805621
# std                    11.681366                  15.933999
# min                     0.325700                   0.599200
# 25%                     1.674400                   1.945600
# 50%                     2.220000                   2.507050
# 75%                     3.142800                   3.520000
# max                    83.000000                  94.500000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO            MÊS            ANO  \
# count                  103392.000000  103392.000000  103392.000000
# mean                        0.046640       6.485067    2011.737001
# std                         0.042114       3.442155       4.410491
# min                         0.000000       1.000000    2004.000000
# 25%                         0.021000       4.000000    2008.000000
# 50%                         0.031000       6.000000    2012.000000
# 75%                         0.061000       9.000000    2016.000000
# max                         0.780000      12.000000    2019.000000
#
#        coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# count             103392.000000                  103392.000000
# mean               52973.958682                      64.706834
# std                30968.261500                     106.115110
# min                    0.000000                       4.596000
# 25%                25964.750000                      12.438000
# 50%                52661.500000                      16.338000
# 75%                79918.250000                      22.470000
# max               106822.000000                     596.142000

# %% [markdown]
# <br/>
#
# Como o resultado do `describe` de um _dataframe_ é outro _dataframe_, podemos filtrar apenas algumas colunas.

# %%
data_final.describe()['PREÇO MÉDIO REVENDA']
# ou data_final['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# count        103392.000000         103392.000000             103392.000000
# mean             10.784472             12.458686                  8.559322
# std              17.685852             20.801190                 13.603686
# min               0.766000              0.999000                  0.506000
# 25%               2.073000              2.330000                  1.795000
# 50%               2.723000              3.000000                  2.335000
# 75%               3.745000              4.150000                  3.307000
# max              99.357000            120.000000                 83.137000

# %%
# Outra forma
data_final[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']].describe()
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# count        103392.000000         103392.000000             103392.000000
# mean             10.784472             12.458686                  8.559322
# std              17.685852             20.801190                 13.603686
# min               0.766000              0.999000                  0.506000
# 25%               2.073000              2.330000                  1.795000
# 50%               2.723000              3.000000                  2.335000
# 75%               3.745000              4.150000                  3.307000
# max              99.357000            120.000000                 83.137000

# %% [markdown]
# **Acessando apenas algumas estatísticas**

# %%
stats
# Out:
#        NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count                 103392.000000        103392.000000
# mean                     240.511935            10.784472
# std                      408.039174            17.685852
# min                        1.000000             0.766000
# 25%                       47.000000             2.073000
# 50%                      108.000000             2.723000
# 75%                      251.000000             3.745000
# max                     4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# min                 0.000000              0.590000              0.999000
# 25%                 0.073000              1.900000              2.330000
# 50%                 0.115000              2.509000              3.000000
# 75%                 0.190000              3.490000              4.150000
# max                10.748000             90.000000            120.000000
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# count         103392.000000             103392.000000
# mean               2.225151                  0.045749
# std                4.375085                  0.024488
# min                0.001000                  0.000000
# 25%                0.282000                  0.030000
# 50%                0.383000                  0.042000
# 75%                0.560000                  0.058000
# max               36.847000                  0.262000
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# count             103392.000000               103392.000000
# mean                   8.559322                    0.559441
# std                   13.603686                    1.256914
# min                    0.506000                    0.000000
# 25%                    1.795000                    0.047000
# 50%                    2.335000                    0.077000
# 75%                    3.307000                    0.151000
# max                   83.137000                   18.385000
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# count              103392.000000              103392.000000
# mean                    7.414814                   9.805621
# std                    11.681366                  15.933999
# min                     0.325700                   0.599200
# 25%                     1.674400                   1.945600
# 50%                     2.220000                   2.507050
# 75%                     3.142800                   3.520000
# max                    83.000000                  94.500000
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO            MÊS            ANO  \
# count                  103392.000000  103392.000000  103392.000000
# mean                        0.046640       6.485067    2011.737001
# std                         0.042114       3.442155       4.410491
# min                         0.000000       1.000000    2004.000000
# 25%                         0.021000       4.000000    2008.000000
# 50%                         0.031000       6.000000    2012.000000
# 75%                         0.061000       9.000000    2016.000000
# max                         0.780000      12.000000    2019.000000
#
#        coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# count             103392.000000                  103392.000000
# mean               52973.958682                      64.706834
# std                30968.261500                     106.115110
# min                    0.000000                       4.596000
# 25%                25964.750000                      12.438000
# 50%                52661.500000                      16.338000
# 75%                79918.250000                      22.470000
# max               106822.000000                     596.142000

# %%
stats.loc[['min', 'max', 'mean']]
# Out:
#       NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# min                       1.000000             0.766000
# max                    4167.000000            99.357000
# mean                    240.511935            10.784472
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# min                0.000000              0.590000              0.999000
# max               10.748000             90.000000            120.000000
# mean               0.652589              9.334931             12.458686
#
#       MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# min               0.001000                  0.000000
# max              36.847000                  0.262000
# mean              2.225151                  0.045749
#
#       PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# min                   0.506000                    0.000000
# max                  83.137000                   18.385000
# mean                  8.559322                    0.559441
#
#       PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# min                    0.325700                   0.599200
# max                   83.000000                  94.500000
# mean                   7.414814                   9.805621
#
#       COEF DE VARIAÇÃO DISTRIBUIÇÃO        MÊS          ANO  \
# min                         0.00000   1.000000  2004.000000
# max                         0.78000  12.000000  2019.000000
# mean                        0.04664   6.485067  2011.737001
#
#       coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# min                   0.000000                       4.596000
# max              106822.000000                     596.142000
# mean              52973.958682                      64.706834

# %%
stats.loc[['min', 'max', 'mean'], 'PREÇO MÉDIO REVENDA']
# Out:
# min      0.766000
# max     99.357000
# mean    10.784472
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats.loc[['min', 'max', 'mean'], ['PREÇO MÉDIO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#       PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# min              0.766000                  0.506000
# max             99.357000                 83.137000
# mean            10.784472                  8.559322

# %% [markdown]
# <br/>
#
# `mean`, `std`, `min`, etc: cada uma das estatísticas do `describe` podem ser computadas individualmente:

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.110
# 1                     0.763                       0.088
# 2                     0.970                       0.095
# 3                     0.830                       0.119
# 4                     0.941                       0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.96660
# 1                     0.5013                    1.05000
# 2                     0.5614                    1.16100
# 3                     0.5991                    1.22242
# 4                     0.7441                    1.03170
#
#    COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 0                          0.133    5  2004           DEFAULT
# 1                          0.115    5  2004           DEFAULT
# 2                          0.098    5  2004           DEFAULT
# 3                          0.143    5  2004           DEFAULT
# 4                          0.082    5  2004           DEFAULT
#
#    coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                         0                          7.728
# 1                         1                          6.972
# 2                         2                          8.334
# 3                         3                          7.572
# 4                         4                          7.086
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Qual é o menor preço mínimo de revenda?

# %%
data_final['PREÇO MÍNIMO REVENDA'].min()
# Out:
# 0.59

# %% [markdown]
# #### Qual é a média e desvio padrão dos preços mínimos de revenda?

# %%
mean = data_final['PREÇO MÍNIMO REVENDA'].mean()
std = data_final['PREÇO MÍNIMO REVENDA'].std()

print(f'A média dos preços mínimos de revenda é {mean:.2f} +- {std:.2f}')
# Out:
# A média dos preços mínimos de revenda é 9.33 +- 15.02

# %% [markdown]
# #### Quais são os estados considerados?

# %%
data_final['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 103387    RIO GRANDE DO NORTE
# 103388      RIO GRANDE DO SUL
# 103389         SANTA CATARINA
# 103390              SAO PAULO
# 103391                SERGIPE
# Name: ESTADO, Length: 103392, dtype: object

# %%
data_final['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
# Array em ordem alfabética
sorted(data_final['ESTADO'].unique())
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %% [markdown]
# #### Quantos registros (aferições) cada estado possui?

# %% [markdown]
# `.value_counts()`:  Conta a frequência dos valores de uma dada variável (de preferência, _categórica_).

# %%
data_final['ESTADO'].value_counts() # Retornas em ordem decrescente, a quantidade de registros/linhas para cada estado
# Out:
# ESTADO
# BAHIA                  4263
# RIO DE JANEIRO         4262
# SAO PAULO              4261
# RIO GRANDE DO SUL      4249
# PARAIBA                4240
# PERNAMBUCO             4236
# SERGIPE                4202
# SANTA CATARINA         4164
# MINAS GERAIS           4142
# ESPIRITO SANTO         4079
# MATO GROSSO DO SUL     4076
# ALAGOAS                4020
# RIO GRANDE DO NORTE    3999
# CEARA                  3964
# PARANA                 3902
# AMAZONAS               3713
# MATO GROSSO            3703
# PARA                   3477
# MARANHAO               3470
# ACRE                   3463
# RORAIMA                3457
# TOCANTINS              3453
# GOIAS                  3449
# RONDONIA               3441
# PIAUI                  3394
# DISTRITO FEDERAL       3317
# AMAPA                  2996
# Name: count, dtype: int64

# %%
data_final['ESTADO'].value_counts().to_frame() # Converte uma Series para um DataFrame
# Out:
#                      count
# ESTADO
# BAHIA                 4263
# RIO DE JANEIRO        4262
# SAO PAULO             4261
# RIO GRANDE DO SUL     4249
# PARAIBA               4240
# PERNAMBUCO            4236
# SERGIPE               4202
# SANTA CATARINA        4164
# MINAS GERAIS          4142
# ESPIRITO SANTO        4079
# MATO GROSSO DO SUL    4076
# ALAGOAS               4020
# RIO GRANDE DO NORTE   3999
# CEARA                 3964
# PARANA                3902
# AMAZONAS              3713
# MATO GROSSO           3703
# PARA                  3477
# MARANHAO              3470
# ACRE                  3463
# RORAIMA               3457
# TOCANTINS             3453
# GOIAS                 3449
# RONDONIA              3441
# PIAUI                 3394
# DISTRITO FEDERAL      3317
# AMAPA                 2996

# %% [markdown]
# <h2>4. Executando funções para cada item de um DataFrame ou Series</h2>
# <hr/>

# %% [markdown]
# Uma alternativa ao `for-loop` que vimos anteriormente e que é _lento_, é usarmos _funções próprias do pandas_ que **aplicam/mapeiam uma dada função a todos os elementos de um DataFrame ou Series**, retornando novos elementos "transformados".

# %% [markdown]
# <img src='./imagens/apply_map_applymap.png' width=300/>
#
#
# Fonte: https://towardsdatascience.com/introduction-to-pandas-apply-applymap-and-map-5d3e044e93ff

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4], 
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]}, 
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# `apply()`: usado para aplicar uma função ao longo de um eixo de um DataFrame ou em valores de uma Series.

# %% [markdown]
# <img src='./imagens/pandas_axis.jpg' width=500/>
#
# Fonte: https://www.allthesnippets.com/browse/pandas/df_axis.html

# %%
def nossa_soma(series):
    return series.sum() # retorna a soma de todos os valores de uma linha

# %%
df['SOMA(A, B, C)'] = df.apply(nossa_soma, axis=1)
df
# Out:
#          A   B    C  SOMA(A, B, C)
# Linha 1  1  10  100            111
# Linha 2  2  20  200            222
# Linha 3  3  30  300            333
# Linha 4  4  40  400            444

# %% [markdown]
# <img src='./imagens/apply_axis_1.png' width=250/>

# %%
df.loc['Linha 5'] = df.apply(nossa_soma, axis=0)
df
# Out:
#           A    B     C  SOMA(A, B, C)
# Linha 1   1   10   100            111
# Linha 2   2   20   200            222
# Linha 3   3   30   300            333
# Linha 4   4   40   400            444
# Linha 5  10  100  1000           1110

# %% [markdown]
# <img src='./imagens/apply_axis_0.png' width=250/>

# %% [markdown]
# ##### Usando `lambda` functions

# %%
# Primeiro filtramos as colunas A, B e C
df['MEDIA(A, B, C)'] = df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis=1)
df
# Out:
#           A    B     C  SOMA(A, B, C)  MEDIA(A, B, C)
# Linha 1   1   10   100            111            37.0
# Linha 2   2   20   200            222            74.0
# Linha 3   3   30   300            333           111.0
# Linha 4   4   40   400            444           148.0
# Linha 5  10  100  1000           1110           370.0

# %% [markdown]
# <img src='./imagens/apply_axis_1_mean.png' width=350/>

# %%
# Aplica a lammbda function abaixo para cada elemento da coluna
df['C * 2'] = df['C'].apply(lambda x: x * 2)
df
# Out:
#           A    B     C  SOMA(A, B, C)  MEDIA(A, B, C)  C * 2
# Linha 1   1   10   100            111            37.0    200
# Linha 2   2   20   200            222            74.0    400
# Linha 3   3   30   300            333           111.0    600
# Linha 4   4   40   400            444           148.0    800
# Linha 5  10  100  1000           1110           370.0   2000

# %%
df['A * 2'] = df['A'] * 2
df
# Out:
#           A    B     C  SOMA(A, B, C)  MEDIA(A, B, C)  C * 2  A * 2
# Linha 1   1   10   100            111            37.0    200      2
# Linha 2   2   20   200            222            74.0    400      4
# Linha 3   3   30   300            333           111.0    600      6
# Linha 4   4   40   400            444           148.0    800      8
# Linha 5  10  100  1000           1110           370.0   2000     20

# %% [markdown]
# <br/>
#
# `applymap()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de um DataFrame.'
#
# Obs.: o panda adverte para não usar mais o `applymap` e sim apenas a função `map`

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4], 
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]}, 
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
# Retorna um novo dataframe com todos os elementos ao quadrado
# Poderíamos usar uma função ao invés de uma lambda function
df.map(lambda x: x ** 2)
# Out:
#           A     B       C
# Linha 1   1   100   10000
# Linha 2   4   400   40000
# Linha 3   9   900   90000
# Linha 4  16  1600  160000

# %% [markdown]
# <br/>
#
# `map()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de uma _Series_.

# %%
nomes = pd.Series(['João', 'Alice', 'Maria', 'Pedro'])
nomes
# Out:
# 0     João
# 1    Alice
# 2    Maria
# 3    Pedro
# dtype: object

# %%
# Retorna uma nova Series com todos os nomes com letras maiúsculas
# Poderíamos usar uma função ao invés de uma lambda function
nomes.map(lambda x: x.upper())
# Out:
# 0     JOÃO
# 1    ALICE
# 2    MARIA
# 3    PEDRO
# dtype: object

# %%
# A função map cria apenas uma cópia, não alterando a Series original
nomes
# Out:
# 0     João
# 1    Alice
# 2    Maria
# 3    Pedro
# dtype: object

# %%
# O pandas já fornece uma série de métodos para manupulação de strings
# Assim, poderíamos usar o código abaixo para obter o mesmo resultado
nomes.str.upper()
# Out:
# 0     JOÃO
# 1    ALICE
# 2    MARIA
# 3    PEDRO
# dtype: object

# %% [markdown]
# <h2>5. Agrupamento</h2>
# <hr/>

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.110
# 1                     0.763                       0.088
# 2                     0.970                       0.095
# 3                     0.830                       0.119
# 4                     0.941                       0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.96660
# 1                     0.5013                    1.05000
# 2                     0.5614                    1.16100
# 3                     0.5991                    1.22242
# 4                     0.7441                    1.03170
#
#    COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 0                          0.133    5  2004           DEFAULT
# 1                          0.115    5  2004           DEFAULT
# 2                          0.098    5  2004           DEFAULT
# 3                          0.143    5  2004           DEFAULT
# 4                          0.082    5  2004           DEFAULT
#
#    coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                         0                          7.728
# 1                         1                          6.972
# 2                         2                          8.334
# 3                         3                          7.572
# 4                         4                          7.086
#
# [5 rows x 23 columns]

# %% [markdown]
# `groupby`: Usado para criar **grupo de elementos** (e.x., baseado nos valores de um atributo). <br/>
# **Funções** podem então ser aplicadas para os _elementos de cada grupo_, de modo que os **resultados de cada grupo são combinados**.

# %%
# Agrupa as linhas da tabela de acordo com suas respectivas regiões
grupos = data_final.groupby('REGIÃO')
grupos

# %%
# Retorna os grupos obtidos pelo groupby
grupos.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14, 15, 16, 17, 18, 19, 40, 41, 42, 43, 44, 45, 46, 67, 68, 69, 70, 71, 72, 73, 94, 95, 96, 97, 98, 99, 100, 121, 122, 123, 124, 125, 126, 127, 148, 149, 150, 151, 152, 153, 154, 175, 176, 177, 178, 179, 180, 181, 202, 203, 204, 205, 206, 207, 208, 229, 230, 231, 232, 233, 234, 235, 256, 257, 258, 259, 260, 261, 262, 283, 284, 285, 286, 287, 288, 289, 310, 311, 312, 313, 314, 315, 316, 337, 338, 339, 340, 341, 342, 343, 364, 365, 366, 367, 368, 369, 370, 391, 392, ...], 'SUDESTE': [20, 21, 22, 23, 47, 48, 49, 50, 74, 75, 76, 77, 101, 102, 103, 104, 128, 129, 130, 131, 155, 156, 157, 158, 182, 183, 184, 185, 209, 210, 211, 212, 236, 237, 238, 239, 263, 264, 265, 266, 290, 291, 292, 293, 317, 318, 319, 320, 344, 345, 346, 347, 371, 372, 373, 374, 398, 399, 400, 401, 425, 426, 427, 428, 452, 453, 454, 455, 479, 480, 481, 482, 506, 507, 508, 509, 533, 534, 535, 536, 560, 561, 562, 563, 587, 588, 589, 590, 614, 615, 616, 617, 641, 642, 643, 644, 668, 669, 670, 671, ...], 'SUL': [24, 25, 26, 51, 52, 53, 78, 79, 80, 105, 106, 107, 132, 133, 134, 159, 160, 161, 186, 187, 188, 213, 214, 215, 240, 241, 242, 267, 268, 269, 294, 295, 296, 321, 322, 323, 348, 349, 350, 375, 376, 377, 402, 403, 404, 429, 430, 431, 456, 457, 458, 483, 484, 485, 510, 511, 512, 537, 538, 539, 564, 565, 566, 591, 592, 593, 618, 619, 620, 645, 646, 647, 672, 673, 674, 699, 700, 701, 726, 727, 728, 753, 754, 755, 780, 781, 782, 807, 808, 809, 834, 835, 836, 861, 862, 863, 888, 889, 890, 915, ...]}

# %%
# Retorna os índices nas linhas/observações de cada grupo
grupos.indices
# Out:
# {'CENTRO OESTE': array([     0,      1,      2, ..., 103363, 103364, 103383], dtype=int64),
#  'NORDESTE': array([     4,      5,      6, ..., 103385, 103387, 103391], dtype=int64),
#  'NORTE': array([    13,     14,     15, ..., 103374, 103375, 103379], dtype=int64),
#  'SUDESTE': array([    20,     21,     22, ..., 103377, 103386, 103390], dtype=int64),
#  'SUL': array([    24,     25,     26, ..., 103376, 103388, 103389], dtype=int64)}

# %%
# Retorna um dataframe apenas com as observações do grupo 'NORDESTE'
grupos.get_group('NORDESTE')
# Out:
#        DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 4        2004-05-09  2004-05-15  NORDESTE              ALAGOAS
# 5        2004-05-09  2004-05-15  NORDESTE                BAHIA
# 6        2004-05-09  2004-05-15  NORDESTE                CEARA
# 7        2004-05-09  2004-05-15  NORDESTE             MARANHAO
# 8        2004-05-09  2004-05-15  NORDESTE              PARAIBA
# ...             ...         ...       ...                  ...
# 103382   2019-06-23  2019-06-29  NORDESTE                CEARA
# 103384   2019-06-23  2019-06-29  NORDESTE              PARAIBA
# 103385   2019-06-23  2019-06-29  NORDESTE           PERNAMBUCO
# 103387   2019-06-23  2019-06-29  NORDESTE  RIO GRANDE DO NORTE
# 103391   2019-06-23  2019-06-29  NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 4       ETANOL HIDRATADO                           103              R$/l
# 5       ETANOL HIDRATADO                           408              R$/l
# 6       ETANOL HIDRATADO                           278              R$/l
# 7       ETANOL HIDRATADO                           105              R$/l
# 8       ETANOL HIDRATADO                           125              R$/l
# ...                  ...                           ...               ...
# 103382               GNV                            16             R$/m3
# 103384               GNV                            11             R$/m3
# 103385               GNV                            12             R$/m3
# 103387               GNV                             7             R$/m3
# 103391               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 4                     1.181                  0.078                 1.050  ...
# 5                     1.383                  0.132                 0.999  ...
# 6                     1.453                  0.218                 1.030  ...
# 7                     1.631                  0.158                 1.350  ...
# 8                     1.284                  0.130                 1.100  ...
# ...                     ...                    ...                   ...  ...
# 103382                3.656                  0.034                 3.580  ...
# 103384                3.688                  0.016                 3.660  ...
# 103385                2.698                  0.260                 2.690  ...
# 103387                3.574                  0.065                 3.499  ...
# 103391                3.697                  0.005                 3.689  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 4                          0.941                       0.077
# 5                          0.957                       0.128
# 6                          1.100                       0.068
# 7                          1.116                       0.091
# 8                          0.931                       0.072
# ...                          ...                         ...
# 103382                     2.780                       0.000
# 103384                     3.068                       0.025
# 103385                     1.907                       0.196
# 103387                     2.756                       0.000
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 4                          0.7441                    1.03170
# 5                          0.5686                    1.35000
# 6                          0.7332                    1.29400
# 7                          0.9923                    1.36183
# 8                          0.7577                    1.29720
# ...                           ...                        ...
# 103382                     2.7802                    2.78020
# 103384                     3.0317                    3.06760
# 103385                     1.7116                    2.07000
# 103387                     2.7560                    2.75600
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 4                               0.082    5  2004           DEFAULT
# 5                               0.134    5  2004           DEFAULT
# 6                               0.062    5  2004           DEFAULT
# 7                               0.082    5  2004           DEFAULT
# 8                               0.077    5  2004           DEFAULT
# ...                               ...  ...   ...               ...
# 103382                          0.000    6  2019           DEFAULT
# 103384                          0.008    6  2019           DEFAULT
# 103385                          0.103    6  2019           DEFAULT
# 103387                          0.000    6  2019           DEFAULT
# 103391                          0.000    6  2019           DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 4                              4                          7.086
# 5                              5                          8.298
# 6                              6                          8.718
# 7                              7                          9.786
# 8                              8                          7.704
# ...                          ...                            ...
# 103382                    106810                         21.936
# 103384                    106814                         22.128
# 103385                    106816                         16.188
# 103387                    106818                         21.444
# 103391                    106822                         22.182
#
# [35788 rows x 23 columns]

# %%
# Descreve algumas características descritivas para as observaçÕes de cada grupo
grupos.describe()
# Out:
#              NÚMERO DE POSTOS PESQUISADOS                                      \
#                                     count        mean         std  min    25%
# REGIÃO
# CENTRO OESTE                      14545.0  144.898453  105.699340  1.0   80.0
# NORDESTE                          35788.0  124.721834  113.110808  1.0   41.0
# NORTE                             24000.0   67.835958   52.961342  1.0   31.0
# SUDESTE                           16744.0  726.068024  787.588935  1.0  168.0
# SUL                               12315.0  366.266423  233.276285  1.0  188.0
#
#                                    PREÇO MÉDIO REVENDA             ...  \
#                 50%    75%     max               count       mean  ...
# REGIÃO                                                             ...
# CENTRO OESTE  128.0  192.0   766.0             14545.0  12.299706  ...
# NORDESTE       95.0  169.0   625.0             35788.0   9.558746  ...
# NORTE          53.0   95.0   383.0             24000.0  12.633086  ...
# SUDESTE       412.0  996.0  4167.0             16744.0   9.828218  ...
# SUL           368.0  563.0  1416.0             12315.0  10.254388  ...
#
#              coluna a partir de lista           PREÇO MÉDIO REVENDA (dólares)  \
#                                   75%       max                         count
# REGIÃO
# CENTRO OESTE                  80299.0  106812.0                       14545.0
# NORDESTE                      79910.5  106822.0                       35788.0
# NORTE                         80343.5  106807.0                       24000.0
# SUDESTE                       79401.5  106821.0                       16744.0
# SUL                           79332.5  106820.0                       12315.0
#
#
#                    mean         std    min     25%     50%     75%      max
# REGIÃO
# CENTRO OESTE  73.798239  119.704635  6.582  12.684  16.866  23.166  596.142
# NORDESTE      57.352477   95.933090  5.850  11.886  15.744  21.480  477.780
# NORTE         75.798516  117.827109  7.356  14.292  17.982  25.386  523.620
# SUDESTE       58.969309   97.709682  4.596  11.262  15.321  21.435  475.152
# SUL           61.526326  101.423263  5.532  11.940  15.582  21.318  432.528
#
# [5 rows x 128 columns]

# %%
grupos.min()
# Out:
#              DATA INICIAL  DATA FINAL            ESTADO           PRODUTO  \
# REGIÃO
# CENTRO OESTE   2004-05-09  2004-05-15  DISTRITO FEDERAL  ETANOL HIDRATADO
# NORDESTE       2004-05-09  2004-05-15           ALAGOAS  ETANOL HIDRATADO
# NORTE          2004-05-09  2004-05-15              ACRE  ETANOL HIDRATADO
# SUDESTE        2004-05-09  2004-05-15    ESPIRITO SANTO  ETANOL HIDRATADO
# SUL            2004-05-09  2004-05-15            PARANA  ETANOL HIDRATADO
#
#               NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# REGIÃO
# CENTRO OESTE                             1           R$/13Kg
# NORDESTE                                 1           R$/13Kg
# NORTE                                    1           R$/13Kg
# SUDESTE                                  1           R$/13Kg
# SUL                                      1           R$/13Kg
#
#               PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO
# CENTRO OESTE                1.097                    0.0
# NORDESTE                    0.975                    0.0
# NORTE                       1.226                    0.0
# SUDESTE                     0.766                    0.0
# SUL                         0.922                    0.0
#
#               PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  ...  \
# REGIÃO                                                    ...
# CENTRO OESTE                  0.87                 1.099  ...
# NORDESTE                      0.79                 0.999  ...
# NORTE                         1.05                 1.300  ...
# SUDESTE                       0.59                 1.099  ...
# SUL                           0.73                 1.199  ...
#
#               PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                     0.737                         0.0
# NORDESTE                         0.586                         0.0
# NORTE                            0.674                         0.0
# SUDESTE                          0.506                         0.0
# SUL                              0.667                         0.0
#
#               PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# REGIÃO
# CENTRO OESTE                    0.38790                     0.8359
# NORDESTE                        0.36320                     0.5992
# NORTE                           0.51022                     0.9612
# SUDESTE                         0.32570                     0.7822
# SUL                             0.43000                     0.7044
#
#               COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# REGIÃO
# CENTRO OESTE                            0.0    1  2004           DEFAULT
# NORDESTE                                0.0    1  2004           DEFAULT
# NORTE                                   0.0    1  2004           DEFAULT
# SUDESTE                                 0.0    1  2004           DEFAULT
# SUL                                     0.0    1  2004           DEFAULT
#
#               coluna a partir de lista PREÇO MÉDIO REVENDA (dólares)
# REGIÃO
# CENTRO OESTE                         0                         6.582
# NORDESTE                             4                         5.850
# NORTE                               13                         7.356
# SUDESTE                             20                         4.596
# SUL                                 24                         5.532
#
# [5 rows x 22 columns]

# %% [markdown]
# <br/>
#
# Também podemos ter agrupamentos por mais de um atributo.

# %%
data_final.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.110
# 1                     0.763                       0.088
# 2                     0.970                       0.095
# 3                     0.830                       0.119
# 4                     0.941                       0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.96660
# 1                     0.5013                    1.05000
# 2                     0.5614                    1.16100
# 3                     0.5991                    1.22242
# 4                     0.7441                    1.03170
#
#    COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 0                          0.133    5  2004           DEFAULT
# 1                          0.115    5  2004           DEFAULT
# 2                          0.098    5  2004           DEFAULT
# 3                          0.143    5  2004           DEFAULT
# 4                          0.082    5  2004           DEFAULT
#
#    coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                         0                          7.728
# 1                         1                          6.972
# 2                         2                          8.334
# 3                         3                          7.572
# 4                         4                          7.086
#
# [5 rows x 23 columns]

# %% [markdown]
# Quais são os preços médios dos Produtos (Combustíveis) para cada região?

# %%
# Agrupa os registros do dataframe primeiramente por suas regiões
# Então, agrupa os registros de cada região (grupo) de acordo com seus produtos
grupos = data_final.groupby(['REGIÃO', 'PRODUTO'])
grupos

# %%
grupos.groups
# Out:
# {('CENTRO OESTE', 'ETANOL HIDRATADO'): [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], ('CENTRO OESTE', 'GASOLINA COMUM'): [11980, 11981, 11982, 11983, 12007, 12008, 12009, 12010, 12034, 12035, 12036, 12037, 12061, 12062, 12063, 12064, 12088, 12089, 12090, 12091, 12115, 12116, 12117, 12118, 12142, 12143, 12144, 12145, 12169, 12170, 12171, 12172, 12196, 12197, 12198, 12199, 12223, 12224, 12225, 12226, 12250, 12251, 12252, 12253, 12277, 12278, 12279, 12280, 12304, 12305, 12306, 12307, 12331, 12332, 12333, 12334, 12358, 12359, 12360, 12361, 12385, 12386, 12387, 12388, 12412, 12413, 12414, 12415, 12439, 12440, 12441, 12442, 12466, 12467, 12468, 12469, 12493, 12494, 12495, 12496, 12520, 12521, 12522, 12523, 12547, 12548, 12549, 12550, 12574, 12575, 12576, 12577, 12601, 12602, 12603, 12604, 12628, 12629, 12630, 12631, ...], ('CENTRO OESTE', 'GLP'): [24019, 24020, 24021, 24022, 24046, 24047, 24048, 24049, 24073, 24074, 24075, 24076, 24100, 24101, 24102, 24103, 24127, 24128, 24129, 24130, 24154, 24155, 24156, 24157, 24181, 24182, 24183, 24184, 24208, 24209, 24210, 24211, 24235, 24236, 24237, 24238, 24262, 24263, 24264, 24265, 24289, 24290, 24291, 24292, 24316, 24317, 24318, 24319, 24343, 24344, 24345, 24346, 24370, 24371, 24372, 24373, 24397, 24398, 24399, 24400, 24424, 24425, 24426, 24427, 24451, 24452, 24453, 24454, 24478, 24479, 24480, 24481, 24505, 24506, 24507, 24508, 24532, 24533, 24534, 24535, 24558, 24559, 24560, 24561, 24585, 24586, 24587, 24588, 24612, 24613, 24614, 24615, 24639, 24640, 24641, 24642, 24666, 24667, 24668, 24669, ...], ('CENTRO OESTE', 'GNV'): [35892, 35907, 35922, 35937, 35952, 35967, 35982, 35997, 36012, 36027, 36042, 36057, 36072, 36087, 36102, 36117, 36132, 36147, 36162, 36177, 36192, 36207, 36222, 36237, 36252, 36267, 36283, 36298, 36313, 36329, 36345, 36360, 36375, 36390, 36405, 36420, 36436, 36451, 36466, 36481, 36495, 36510, 36525, 36541, 36557, 36572, 36588, 36604, 36620, 36635, 36650, 36665, 36680, 36695, 36710, 36725, 36740, 36755, 36770, 36785, 36800, 36815, 36830, 36845, 36860, 36875, 36890, 36918, 36932, 36948, 36962, 36991, 37006, 37021, 37037, 37053, 37068, 37084, 37100, 37116, 37132, 37148, 37164, 37180, 37196, 37212, 37228, 37244, 37259, 37275, 37291, 37307, 37323, 37339, 37355, 37371, 37387, 37403, 37419, 37435, ...], ('CENTRO OESTE', 'ÓLEO DIESEL'): [42612, 42613, 42614, 42615, 42639, 42640, 42641, 42642, 42666, 42667, 42668, 42669, 42693, 42694, 42695, 42696, 42720, 42721, 42722, 42723, 42747, 42748, 42749, 42750, 42774, 42775, 42776, 42777, 42801, 42802, 42803, 42804, 42828, 42829, 42830, 42831, 42855, 42856, 42857, 42858, 42882, 42883, 42884, 42885, 42909, 42910, 42911, 42912, 42936, 42937, 42938, 42939, 42963, 42964, 42965, 42966, 42990, 42991, 42992, 42993, 43017, 43018, 43019, 43020, 43044, 43045, 43046, 43047, 43071, 43072, 43073, 43074, 43098, 43099, 43100, 43101, 43125, 43126, 43127, 43128, 43152, 43153, 43154, 43155, 43179, 43180, 43181, 43182, 43206, 43207, 43208, 43209, 43233, 43234, 43235, 43236, 43260, 43261, 43262, 43263, ...], ('CENTRO OESTE', 'ÓLEO DIESEL S10'): [54834, 54835, 54973, 54975, 54976, 55117, 55119, 55120, 55260, 55262, 55264, 55265, 55405, 55407, 55408, 55549, 55551, 55552, 55692, 55694, 55695, 55835, 55837, 55838, 55981, 55983, 55984, 56128, 56130, 56131, 56276, 56278, 56279, 56421, 56423, 56424, 56566, 56568, 56569, 56711, 56713, 56714, 56854, 56856, 56858, 56859, 57002, 57004, 57006, 57007, 57148, 57150, 57152, 57153, 57293, 57295, 57297, 57298, 57440, 57442, 57444, 57445, 57586, 57588, 57590, 57591, 57732, 57734, 57736, 57737, ...

# %%
#grupos.mean() # descobrir porquê não está rodando

# %%
grupos['PREÇO MÉDIO REVENDA'].mean()
# Out:
# REGIÃO        PRODUTO
# CENTRO OESTE  ETANOL HIDRATADO     2.135670
#               GASOLINA COMUM       3.077476
#               GLP                 48.176747
#               GNV                  1.856312
#               ÓLEO DIESEL          2.481286
#               ÓLEO DIESEL S10      3.294752
# NORDESTE      ETANOL HIDRATADO     2.320266
#               GASOLINA COMUM       3.001887
#               GLP                 41.966090
#               GNV                  1.881722
#               ÓLEO DIESEL          2.346950
#               ÓLEO DIESEL S10      3.041966
# NORTE         ETANOL HIDRATADO     2.511624
#               GASOLINA COMUM       3.149501
#               GLP                 47.065572
#               GNV                  2.084399
#               ÓLEO DIESEL          2.571048
#               ÓLEO DIESEL S10      3.316231
# SUDESTE       ETANOL HIDRATADO     2.163621
#               GASOLINA COMUM       3.000565
#               GLP                 42.081544
#               GNV                  1.716074
#               ÓLEO DIESEL          2.339699
#               ÓLEO DIESEL S10      3.056194
# SUL           ETANOL HIDRATADO     2.268156
#               GASOLINA COMUM       2.972569
#               GLP                 43.490318
#               GNV                  1.865612
#               ÓLEO DIESEL          2.332293
#               ÓLEO DIESEL S10      2.981775
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
grupos['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                                 count       mean        std     min       25%  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO  3122.0   2.135670   0.561465   1.162   1.71400
#              GASOLINA COMUM    3134.0   3.077476   0.615290   1.936   2.66725
#              GLP               3098.0  48.176747  15.204045  28.791  37.33300
#              GNV                847.0   1.856312   0.423861   1.097   1.56900
#              ÓLEO DIESEL       3134.0   2.481286   0.626930   1.435   2.03300
#              ÓLEO DIESEL S10   1210.0   3.294752   0.421234   2.305   2.92425
# NORDESTE     ETANOL HIDRATADO  7046.0   2.320266   0.604374   1.181   1.82500
#              GASOLINA COMUM    7063.0   3.001887   0.640696   1.949   2.58400
#              GLP               6410.0  41.966090  12.063743  28.367  33.22875
#              GNV               5176.0   1.881722   0.522996   0.975   1.59600
#              ÓLEO DIESEL       7061.0   2.346950   0.605705   1.313   1.90000
#              ÓLEO DIESEL S10   3032.0   3.041966   0.441550   2.130   2.60000
# NORTE        ETANOL HIDRATADO  5177.0   2.511624   0.646781   1.226   2.03300
#              GASOLINA COMUM    5464.0   3.149501   0.641249   1.995   2.70475
#              GLP               5327.0  47.065572  14.553748  28.086  36.32950
#              GNV                243.0   2.084399   0.622229   1.399   1.39900
#              ÓLEO DIESEL       5465.0   2.571048   0.650994   1.450   2.08600
#              ÓLEO DIESEL S10   2324.0   3.316231   0.529044   2.193   2.88300
# SUDESTE      ETANOL HIDRATADO  3137.0   2.163621   0.651486   0.766   1.69200
#              GASOLINA COMUM    3140.0   3.000565   0.698573   1.888   2.50200
#              GLP               3137.0  42.081544  11.524738  28.026  33.63600
#              GNV               2841.0   1.716074   0.462098   0.996   1.42400
#              ÓLEO DIESEL       3140.0   2.339699   0.588641   1.356   1.87600
#              ÓLEO DIESEL S10   1349.0   3.056194   0.418396   2.180   2.65000
# SUL          ETANOL HIDRATADO  2353.0   2.268156   0.702877   0.922   1.72100
#              GASOLINA COMUM    2354.0   2.972569   0.623557   1.961   2.54300
#              GLP               2343.0  43.490318  11.640755  29.440  34.79250
#              GNV               1899.0   1.865612   0.490703   1.168   1.49900
#              ÓLEO DIESEL       2354.0   2.332293   0.527845   1.374   1.95100
#              ÓLEO DIESEL S10   1012.0   2.981775   0.365470   2.151   2.66300
#
#                                    50%       75%     max
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO   2.0005   2.47900   3.598
#              GASOLINA COMUM     2.8565   3.45975   4.963
#              GLP               42.8385  55.90425  99.357
#              GNV                1.7490   2.16800   3.239
#              ÓLEO DIESEL        2.2465   3.01900   4.162
#              ÓLEO DIESEL S10    3.3540   3.61900   4.200
# NORDESTE     ETANOL HIDRATADO   2.1860   2.67000   3.927
#              GASOLINA COMUM     2.7410   3.42450   4.951
#              GLP               36.8550  48.35100  79.630
#              GNV                1.8005   2.01125   3.811
#              ÓLEO DIESEL        2.0820   2.86700   4.010
#              ÓLEO DIESEL S10    3.0865   3.33800   4.027
# NORTE        ETANOL HIDRATADO   2.3390   2.89600   4.102
#              GASOLINA COMUM     2.9330   3.58475   5.362
#              GLP               42.3110  54.07500  87.270
#              GNV                2.0600   2.65000   3.240
#              ÓLEO DIESEL        2.3390   3.08200   4.774
#              ÓLEO DIESEL S10    3.3155   3.65300   4.878
# SUDESTE      ETANOL HIDRATADO   2.0430   2.56700   4.115
#              GASOLINA COMUM     2.7930   3.45150   5.119
#              GLP               38.2800  49.25900  79.192
#              GNV                1.6630   1.90400   3.399
#              ÓLEO DIESEL        2.0825   2.82500   3.994
#              ÓLEO DIESEL S10    3.0910   3.38600   4.080
# SUL          ETANOL HIDRATADO   2.1130   2.60100   4.287
#              GASOLINA COMUM     2.7315   3.34225   4.953
#              GLP               39.9760  48.73350  72.088
#              GNV                1.7020   2.15950   3.476
#              ÓLEO DIESEL        2.0900   2.78450   3.800
#              ÓLEO DIESEL S10    2.9910   3.25200   3.815

# %% [markdown]
# <br/>
#
# `.agg`: **agrega (roda)** uma série de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
import numpy as np
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [np.nan, np.nan, np.nan]],
                  columns=['A', 'B', 'C'])
df
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0
# 3  NaN  NaN  NaN

# %%
df.agg([sum, min]) # ignora o NaN
# Out:
# C:\Users\rudaa\AppData\Local\Temp\ipykernel_388\478521018.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.agg([sum, min]) # ignora o NaN
# C:\Users\rudaa\AppData\Local\Temp\ipykernel_388\478521018.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.agg([sum, min]) # ignora o NaN
#         A     B     C
# sum  12.0  15.0  18.0
# min   1.0   2.0   3.0

# %%
grupos = data_final.groupby('REGIÃO')
grupos

# %%
# Computa o menor e maior valor do 'PREÇO MÉDIO REVENDA' para cada região (grupo)
grupos['PREÇO MÉDIO REVENDA'].agg([min,max])
# Out:
# C:\Users\rudaa\AppData\Local\Temp\ipykernel_388\4272329806.py:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grupos['PREÇO MÉDIO REVENDA'].agg([min,max])
# C:\Users\rudaa\AppData\Local\Temp\ipykernel_388\4272329806.py:2: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grupos['PREÇO MÉDIO REVENDA'].agg([min,max])
#                 min     max
# REGIÃO
# CENTRO OESTE  1.097  99.357
# NORDESTE      0.975  79.630
# NORTE         1.226  87.270
# SUDESTE       0.766  79.192
# SUL           0.922  72.088

# %% [markdown]
# <h2>6. Ordenação</h2>
# <hr/>

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# `.sort_values()`: ordena valores ao longo de um eixo.

# %%
notas.sort_values(by='nota_final')
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 2   José     19         6.0
# 1  Maria     21        10.0
# 3  Alice     20        10.0

# %% [markdown]
# Por padrão, o método retorna uma cópia dos dados ordenados em **ordem crescente (ascendente)**. Podemos alterar isso pelo argumento `ascending`.

# %%
notas.sort_values(by='nota_final', ascending=False)  
# adicionar o .reset_index(drop=True) vai resetar os índices para começar a contar do 0 de novo
# Out:
#     nome  idade  nota_final
# 1  Maria     21        10.0
# 3  Alice     20        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# <br/>
#
# Podemos ordenar a partir de **mais de uma coluna**:

# %%
# As notas de Maria e Alice são iguais, mas para melhorar a ordenação vamos colocar um segundo critério.
# Em caso de empate das notas, os dados serão ordenados em ordem alfabética
# Ordem decrescente na nota (False) e crescente na ordem alfabética (True)
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True])
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# Ordena os registros, primeiramente, pela coluna 'nota_final' em **ordem descrente**. <br/>
# Então, reordena os registros _"empatados"_, ou seja, com a **mesma nota final**, em _ordem alfabética_ (ordem crescente).

# %% [markdown]
# <br/>
#
# Note que o dataframe original **não foi alterado** após a ordenação.

# %%
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# Para alterá-lo, use o argumento `inplace=True`:

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True], inplace=True)

# %%
notas
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %%
notas.reset_index(drop=True)
# Out:
#     nome  idade  nota_final
# 0  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3   João     20         5.0

# %% [markdown]
# <h2>7. Exercícios</h2>
# <hr/>

# %% [markdown]
# Vamos aplicar os conceitos que vimos em alguns exercícios. <br/>
# Para isso, utilizaremos o dataset de _preços de combustíveis no Brasil_.
#
# Como há apenas medições de janeiro a junho para o ano de 2019, resolvemos **remover os dados** deste ano da análise.

# %%
data_final
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103387   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 103389   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 103390   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 103391   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# 1       ETANOL HIDRATADO                           387              R$/l
# 2       ETANOL HIDRATADO                           192              R$/l
# 3       ETANOL HIDRATADO                           162              R$/l
# 4       ETANOL HIDRATADO                           103              R$/l
# ...                  ...                           ...               ...
# 103387               GNV                             7             R$/m3
# 103388               GNV                            23             R$/m3
# 103389               GNV                            24             R$/m3
# 103390               GNV                            52             R$/m3
# 103391               GNV                             4             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                     1.288                  0.016                 1.190  ...
# 1                     1.162                  0.114                 0.890  ...
# 2                     1.389                  0.097                 1.180  ...
# 3                     1.262                  0.070                 1.090  ...
# 4                     1.181                  0.078                 1.050  ...
# ...                     ...                    ...                   ...  ...
# 103387                3.574                  0.065                 3.499  ...
# 103388                3.401                  0.129                 3.230  ...
# 103389                2.912                  0.190                 2.699  ...
# 103390                3.020                  0.229                 2.699  ...
# 103391                3.697                  0.005                 3.689  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.110
# 1                          0.763                       0.088
# 2                          0.970                       0.095
# 3                          0.830                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 103387                     2.756                       0.000
# 103388                     2.451                       0.402
# 103389                     1.998                       0.000
# 103390                     2.374                       0.165
# 103391                     2.518                       0.000
#
#         PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                          0.4201                    0.96660
# 1                          0.5013                    1.05000
# 2                          0.5614                    1.16100
# 3                          0.5991                    1.22242
# 4                          0.7441                    1.03170
# ...                           ...                        ...
# 103387                     2.7560                    2.75600
# 103388                     1.9842                    2.86610
# 103389                     1.9981                    1.99810
# 103390                     2.0179                    2.50930
# 103391                     2.5175                    2.51750
#
#         COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 0                               0.133    5  2004           DEFAULT
# 1                               0.115    5  2004           DEFAULT
# 2                               0.098    5  2004           DEFAULT
# 3                               0.143    5  2004           DEFAULT
# 4                               0.082    5  2004           DEFAULT
# ...                               ...  ...   ...               ...
# 103387                          0.000    6  2019           DEFAULT
# 103388                          0.164    6  2019           DEFAULT
# 103389                          0.000    6  2019           DEFAULT
# 103390                          0.070    6  2019           DEFAULT
# 103391                          0.000    6  2019           DEFAULT
#
#         coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                              0                          7.728
# 1                              1                          6.972
# 2                              2                          8.334
# 3                              3                          7.572
# 4                              4                          7.086
# ...                          ...                            ...
# 103387                    106818                         21.444
# 103388                    106819                         20.406
# 103389                    106820                         17.472
# 103390                    106821                         18.120
# 103391                    106822                         22.182
#
# [103392 rows x 23 columns]

# %%
data_sem_2019 = data_final.query('ANO != 2019')
data_sem_2019
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0       2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1       2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2       2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3       2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4       2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# 1      ETANOL HIDRATADO                           387              R$/l
# 2      ETANOL HIDRATADO                           192              R$/l
# 3      ETANOL HIDRATADO                           162              R$/l
# 4      ETANOL HIDRATADO                           103              R$/l
# ...                 ...                           ...               ...
# 99734               GNV                           122             R$/m3
# 99735               GNV                            10             R$/m3
# 99736               GNV                            16             R$/m3
# 99737               GNV                            15             R$/m3
# 99738               GNV                            41             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                    1.288                  0.016                 1.190  ...
# 1                    1.162                  0.114                 0.890  ...
# 2                    1.389                  0.097                 1.180  ...
# 3                    1.262                  0.070                 1.090  ...
# 4                    1.181                  0.078                 1.050  ...
# ...                    ...                    ...                   ...  ...
# 99734                3.080                  0.262                 2.798  ...
# 99735                3.465                  0.060                 3.370  ...
# 99736                3.402                  0.103                 3.199  ...
# 99737                2.944                  0.124                 2.790  ...
# 99738                2.353                  0.451                 1.999  ...
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.110
# 1                         0.763                       0.088
# 2                         0.970                       0.095
# 3                         0.830                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 99734                     2.381                       0.161
# 99735                     2.706                       0.000
# 99736                     2.106                       0.249
# 99737                     2.274                       0.283
# 99738                     1.886                       0.250
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.96660
# 1                         0.5013                    1.05000
# 2                         0.5614                    1.16100
# 3                         0.5991                    1.22242
# 4                         0.7441                    1.03170
# ...                          ...                        ...
# 99734                     2.1670                    2.86970
# 99735                     2.7059                    2.70590
# 99736                     1.8775                    2.37240
# 99737                     1.8738                    2.27400
# 99738                     1.6400                    2.33200
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 0                              0.133    5  2004           DEFAULT
# 1                              0.115    5  2004           DEFAULT
# 2                              0.098    5  2004           DEFAULT
# 3                              0.143    5  2004           DEFAULT
# 4                              0.082    5  2004           DEFAULT
# ...                              ...  ...   ...               ...
# 99734                          0.068   12  2018           DEFAULT
# 99735                          0.000   12  2018           DEFAULT
# 99736                          0.118   12  2018           DEFAULT
# 99737                          0.124   12  2018           DEFAULT
# 99738                          0.133   12  2018           DEFAULT
#
#        coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                             0                          7.728
# 1                             1                          6.972
# 2                             2                          8.334
# 3                             3                          7.572
# 4                             4                          7.086
# ...                         ...                            ...
# 99734                    103063                         18.480
# 99735                    103064                         20.790
# 99736                    103065                         20.412
# 99737                    103066                         17.664
# 99738                    103067                         14.118
#
# [99739 rows x 23 columns]

# %% [markdown]
# Note que temos um novo dataframe com 99739 linhas, mas com índices fora desse intervalo. <br/>
# Acontece que os registros mantiveram seus índices originais após a query. <br/>
#
# Para resetar os índices de _0 a num_linhas-1_, basta usarmos o método `.reset_index()`.

# %%
data_sem_2019.reset_index()
# Out:
#        index DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0          0   2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1          1   2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2          2   2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3          3   2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4          4   2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...      ...          ...         ...           ...                  ...
# 99734  99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735  99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736  99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737  99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738  99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# 1      ETANOL HIDRATADO                           387              R$/l
# 2      ETANOL HIDRATADO                           192              R$/l
# 3      ETANOL HIDRATADO                           162              R$/l
# 4      ETANOL HIDRATADO                           103              R$/l
# ...                 ...                           ...               ...
# 99734               GNV                           122             R$/m3
# 99735               GNV                            10             R$/m3
# 99736               GNV                            16             R$/m3
# 99737               GNV                            15             R$/m3
# 99738               GNV                            41             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                    1.288                  0.016  ...
# 1                    1.162                  0.114  ...
# 2                    1.389                  0.097  ...
# 3                    1.262                  0.070  ...
# 4                    1.181                  0.078  ...
# ...                    ...                    ...  ...
# 99734                3.080                  0.262  ...
# 99735                3.465                  0.060  ...
# 99736                3.402                  0.103  ...
# 99737                2.944                  0.124  ...
# 99738                2.353                  0.451  ...
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.110
# 1                         0.763                       0.088
# 2                         0.970                       0.095
# 3                         0.830                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 99734                     2.381                       0.161
# 99735                     2.706                       0.000
# 99736                     2.106                       0.249
# 99737                     2.274                       0.283
# 99738                     1.886                       0.250
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.96660
# 1                         0.5013                    1.05000
# 2                         0.5614                    1.16100
# 3                         0.5991                    1.22242
# 4                         0.7441                    1.03170
# ...                          ...                        ...
# 99734                     2.1670                    2.86970
# 99735                     2.7059                    2.70590
# 99736                     1.8775                    2.37240
# 99737                     1.8738                    2.27400
# 99738                     1.6400                    2.33200
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 0                              0.133    5  2004           DEFAULT
# 1                              0.115    5  2004           DEFAULT
# 2                              0.098    5  2004           DEFAULT
# 3                              0.143    5  2004           DEFAULT
# 4                              0.082    5  2004           DEFAULT
# ...                              ...  ...   ...               ...
# 99734                          0.068   12  2018           DEFAULT
# 99735                          0.000   12  2018           DEFAULT
# 99736                          0.118   12  2018           DEFAULT
# 99737                          0.124   12  2018           DEFAULT
# 99738                          0.133   12  2018           DEFAULT
#
#        coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                             0                          7.728
# 1                             1                          6.972
# 2                             2                          8.334
# 3                             3                          7.572
# 4                             4                          7.086
# ...                         ...                            ...
# 99734                    103063                         18.480
# 99735                    103064                         20.790
# 99736                    103065                         20.412
# 99737                    103066                         17.664
# 99738                    103067                         14.118
#
# [99739 rows x 24 columns]

# %% [markdown]
# Os índices agora foram **resetados**. Porém, os índices antigos se transformaram em _uma nova coluna_ chamada 'index'. <br/>
# Para removê-la durante o _reset_, basta passarmos o argumento `drop=True`.

# %%
data_sem_2019.reset_index(drop=True)
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0       2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1       2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2       2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3       2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4       2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 99734   2018-12-30  2019-01-05       SUDESTE       RIO DE JANEIRO
# 99735   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 99736   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 99737   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 99738   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0      ETANOL HIDRATADO                           127              R$/l
# 1      ETANOL HIDRATADO                           387              R$/l
# 2      ETANOL HIDRATADO                           192              R$/l
# 3      ETANOL HIDRATADO                           162              R$/l
# 4      ETANOL HIDRATADO                           103              R$/l
# ...                 ...                           ...               ...
# 99734               GNV                           122             R$/m3
# 99735               GNV                            10             R$/m3
# 99736               GNV                            16             R$/m3
# 99737               GNV                            15             R$/m3
# 99738               GNV                            41             R$/m3
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                    1.288                  0.016                 1.190  ...
# 1                    1.162                  0.114                 0.890  ...
# 2                    1.389                  0.097                 1.180  ...
# 3                    1.262                  0.070                 1.090  ...
# 4                    1.181                  0.078                 1.050  ...
# ...                    ...                    ...                   ...  ...
# 99734                3.080                  0.262                 2.798  ...
# 99735                3.465                  0.060                 3.370  ...
# 99736                3.402                  0.103                 3.199  ...
# 99737                2.944                  0.124                 2.790  ...
# 99738                2.353                  0.451                 1.999  ...
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                         0.825                       0.110
# 1                         0.763                       0.088
# 2                         0.970                       0.095
# 3                         0.830                       0.119
# 4                         0.941                       0.077
# ...                         ...                         ...
# 99734                     2.381                       0.161
# 99735                     2.706                       0.000
# 99736                     2.106                       0.249
# 99737                     2.274                       0.283
# 99738                     1.886                       0.250
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.96660
# 1                         0.5013                    1.05000
# 2                         0.5614                    1.16100
# 3                         0.5991                    1.22242
# 4                         0.7441                    1.03170
# ...                          ...                        ...
# 99734                     2.1670                    2.86970
# 99735                     2.7059                    2.70590
# 99736                     1.8775                    2.37240
# 99737                     1.8738                    2.27400
# 99738                     1.6400                    2.33200
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 0                              0.133    5  2004           DEFAULT
# 1                              0.115    5  2004           DEFAULT
# 2                              0.098    5  2004           DEFAULT
# 3                              0.143    5  2004           DEFAULT
# 4                              0.082    5  2004           DEFAULT
# ...                              ...  ...   ...               ...
# 99734                          0.068   12  2018           DEFAULT
# 99735                          0.000   12  2018           DEFAULT
# 99736                          0.118   12  2018           DEFAULT
# 99737                          0.124   12  2018           DEFAULT
# 99738                          0.133   12  2018           DEFAULT
#
#        coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 0                             0                          7.728
# 1                             1                          6.972
# 2                             2                          8.334
# 3                             3                          7.572
# 4                             4                          7.086
# ...                         ...                            ...
# 99734                    103063                         18.480
# 99735                    103064                         20.790
# 99736                    103065                         20.412
# 99737                    103066                         17.664
# 99738                    103067                         14.118
#
# [99739 rows x 23 columns]

# %% [markdown]
# ### 7.1 Qual a proporção de postos pesquisados para cada combustível em cada região

# %%
grupo_produtos = data_sem_2019.groupby('PRODUTO')
grupo_produtos

# %%
grupo_produtos['REGIÃO'].value_counts().to_frame()
# Out:
#                                count
# PRODUTO          REGIÃO
# ETANOL HIDRATADO NORDESTE       6821
#                  NORTE          5021
#                  SUDESTE        3039
#                  CENTRO OESTE   3022
#                  SUL            2278
# GASOLINA COMUM   NORDESTE       6838
#                  NORTE          5289
#                  SUDESTE        3040
#                  CENTRO OESTE   3034
#                  SUL            2279
# GLP              NORDESTE       6185
#                  NORTE          5152
#                  SUDESTE        3037
#                  CENTRO OESTE   2998
#                  SUL            2268
# GNV              NORDESTE       5030
#                  SUDESTE        2772
#                  SUL            1847
#                  CENTRO OESTE    825
#                  NORTE           233
# ÓLEO DIESEL      NORDESTE       6836
#                  NORTE          5290
#                  SUDESTE        3040
#                  CENTRO OESTE   3034
#                  SUL            2279
# ÓLEO DIESEL S10  NORDESTE       2807
#                  NORTE          2149
#                  SUDESTE        1249
#                  CENTRO OESTE   1110
#                  SUL             937

# %% [markdown]
# ### 7.2 Como os preços da Gasolina Comum em São Paulo variaram em 2018?

# %%
data_sem_2019.query('PRODUTO == "GASOLINA COMUM" and ESTADO == "SAO PAULO" and ANO == 2018')
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO         PRODUTO  \
# 92319   2018-01-07  2018-01-13  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92465   2018-01-14  2018-01-20  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92610   2018-01-21  2018-01-27  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92755   2018-01-28  2018-02-03  SUDESTE  SAO PAULO  GASOLINA COMUM
# 92901   2018-02-04  2018-02-10  SUDESTE  SAO PAULO  GASOLINA COMUM
# 93048   2018-02-11  2018-02-17  SUDESTE  SAO PAULO  GASOLINA COMUM
# 93192   2018-02-18  2018-02-24  SUDESTE  SAO PAULO  GASOLINA COMUM
# 93339   2018-02-25  2018-03-03  SUDESTE  SAO PAULO  GASOLINA COMUM
# 93487   2018-03-04  2018-03-10  SUDESTE  SAO PAULO  GASOLINA COMUM
# 93634   2018-03-11  2018-03-17  SUDESTE  SAO PAULO  GASOLINA COMUM
# 93778   2018-03-18  2018-03-24  SUDESTE  SAO PAULO  GASOLINA COMUM
# 93924   2018-03-25  2018-03-31  SUDESTE  SAO PAULO  GASOLINA COMUM
# 94070   2018-04-01  2018-04-07  SUDESTE  SAO PAULO  GASOLINA COMUM
# 94215   2018-04-08  2018-04-14  SUDESTE  SAO PAULO  GASOLINA COMUM
# 94361   2018-04-15  2018-04-21  SUDESTE  SAO PAULO  GASOLINA COMUM
# 94508   2018-04-22  2018-04-28  SUDESTE  SAO PAULO  GASOLINA COMUM
# 94656   2018-04-29  2018-05-05  SUDESTE  SAO PAULO  GASOLINA COMUM
# 94804   2018-05-06  2018-05-12  SUDESTE  SAO PAULO  GASOLINA COMUM
# 94951   2018-05-13  2018-05-19  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95098   2018-05-20  2018-05-26  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95211   2018-05-27  2018-06-02  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95342   2018-06-03  2018-06-09  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95486   2018-06-10  2018-06-16  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95633   2018-06-17  2018-06-23  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95779   2018-06-24  2018-06-30  SUDESTE  SAO PAULO  GASOLINA COMUM
# 95922   2018-07-01  2018-07-07  SUDESTE  SAO PAULO  GASOLINA COMUM
# 96069   2018-07-08  2018-07-14  SUDESTE  SAO PAULO  GASOLINA COMUM
# 96217   2018-07-15  2018-07-21  SUDESTE  SAO PAULO  GASOLINA COMUM
# 96362   2018-07-22  2018-07-28  SUDESTE  SAO PAULO  GASOLINA COMUM
# 96507   2018-07-29  2018-08-04  SUDESTE  SAO PAULO  GASOLINA COMUM
# 96651   2018-08-05  2018-08-11  SUDESTE  SAO PAULO  GASOLINA COMUM
# 96799   2018-08-12  2018-08-18  SUDESTE  SAO PAULO  GASOLINA COMUM
# 96943   2018-08-19  2018-08-25  SUDESTE  SAO PAULO  GASOLINA COMUM
# 97086   2018-08-26  2018-09-01  SUDESTE  SAO PAULO  GASOLINA COMUM
# 97230   2018-09-02  2018-09-08  SUDESTE  SAO PAULO  GASOLINA COMUM
# 97378   2018-09-09  2018-09-15  SUDESTE  SAO PAULO  GASOLINA COMUM
# 97527   2018-09-16  2018-09-22  SUDESTE  SAO PAULO  GASOLINA COMUM
# 97675   2018-09-23  2018-09-29  SUDESTE  SAO PAULO  GASOLINA COMUM
# 97820   2018-09-30  2018-10-06  SUDESTE  SAO PAULO  GASOLINA COMUM
# 97965   2018-10-07  2018-10-13  SUDESTE  SAO PAULO  GASOLINA COMUM
# 98112   2018-10-14  2018-10-20  SUDESTE  SAO PAULO  GASOLINA COMUM
# 98259   2018-10-21  2018-10-27  SUDESTE  SAO PAULO  GASOLINA COMUM
# 98401   2018-10-28  2018-11-03  SUDESTE  SAO PAULO  GASOLINA COMUM
# 98545   2018-11-04  2018-11-10  SUDESTE  SAO PAULO  GASOLINA COMUM
# 98689   2018-11-11  2018-11-17  SUDESTE  SAO PAULO  GASOLINA COMUM
# 98831   2018-11-18  2018-11-24  SUDESTE  SAO PAULO  GASOLINA COMUM
# 98977   2018-11-25  2018-12-01  SUDESTE  SAO PAULO  GASOLINA COMUM
# 99122   2018-12-02  2018-12-08  SUDESTE  SAO PAULO  GASOLINA COMUM
# 99266   2018-12-09  2018-12-15  SUDESTE  SAO PAULO  GASOLINA COMUM
# 99410   2018-12-16  2018-12-22  SUDESTE  SAO PAULO  GASOLINA COMUM
# 99553   2018-12-23  2018-12-29  SUDESTE  SAO PAULO  GASOLINA COMUM
# 99698   2018-12-30  2019-01-05  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 92319                          1641              R$/l                3.988
# 92465                          1648              R$/l                4.002
# 92610                          1648              R$/l                4.006
# 92755                          1644              R$/l                4.019
# 92901                          1646              R$/l                4.004
# 93048                          1640              R$/l                4.014
# 93192                          1637              R$/l                4.008
# 93339                          1638              R$/l                3.992
# 93487                          1637              R$/l                3.970
# 93634                          1644              R$/l                4.003
# 93778                          1644              R$/l                3.988
# 93924                          1643              R$/l                3.992
# 94070                          1646              R$/l                4.007
# 94215                          1646              R$/l                4.008
# 94361                          1645              R$/l                4.006
# 94508                          1643              R$/l                4.035
# 94656                          1644              R$/l                4.005
# 94804                          1644              R$/l                4.032
# 94951                          1643              R$/l                4.056
# 95098                          1619              R$/l                4.196
# 95211                           102              R$/l                4.502
# 95342                          1560              R$/l                4.416
# 95486                          1616              R$/l                4.349
# 95633                          1646              R$/l                4.326
# 95779                          1643              R$/l                4.274
# 95922                          1637              R$/l                4.272
# 96069                          1640              R$/l                4.259
# 96217                          1641              R$/l                4.268
# 96362                          1644              R$/l                4.241
# 96507                          1639              R$/l                4.235
# 96651                          1640              R$/l                4.221
# 96799                          1646              R$/l                4.208
# 96943                          1643              R$/l                4.189
# 97086                          1638              R$/l                4.224
# 97230                          1640              R$/l                4.296
# 97378                          1641              R$/l                4.409
# 97527                          1639              R$/l                4.414
# 97675                          1639              R$/l                4.476
# 97820                          1639              R$/l                4.469
# 97965                          1643              R$/l                4.499
# 98112                          1645              R$/l                4.512
# 98259                          1641              R$/l                4.506
# 98401                          1641              R$/l                4.490
# 98545                          1645              R$/l                4.452
# 98689                          1643              R$/l                4.377
# 98831                          1641              R$/l                4.332
# 98977                          1641              R$/l                4.291
# 99122                          1648              R$/l                4.187
# 99266                          1649              R$/l                4.148
# 99410                          1637              R$/l                4.129
# 99553                          1641              R$/l                4.129
# 99698                          1643              R$/l                4.113
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 92319                  0.156                 3.499  ...
# 92465                  0.155                 3.549  ...
# 92610                  0.160                 3.499  ...
# 92755                  0.156                 3.579  ...
# 92901                  0.157                 3.579  ...
# 93048                  0.153                 3.499  ...
# 93192                  0.161                 3.559  ...
# 93339                  0.164                 3.479  ...
# 93487                  0.161                 3.479  ...
# 93634                  0.155                 3.499  ...
# 93778                  0.154                 3.499  ...
# 93924                  0.159                 3.499  ...
# 94070                  0.171                 3.495  ...
# 94215                  0.161                 3.499  ...
# 94361                  0.159                 3.499  ...
# 94508                  0.168                 3.499  ...
# 94656                  0.158                 3.488  ...
# 94804                  0.171                 3.369  ...
# 94951                  0.160                 3.499  ...
# 95098                  0.187                 3.499  ...
# 95211                  0.199                 3.898  ...
# 95342                  0.155                 3.599  ...
# 95486                  0.150                 3.899  ...
# 95633                  0.157                 3.799  ...
# 95779                  0.167                 3.699  ...
# 95922                  0.178                 3.699  ...
# 96069                  0.168                 3.779  ...
# 96217                  0.171                 3.699  ...
# 96362                  0.175                 3.649  ...
# 96507                  0.182                 3.679  ...
# 96651                  0.192                 3.679  ...
# 96799                  0.189                 3.679  ...
# 96943                  0.189                 3.649  ...
# 97086                  0.185                 3.679  ...
# 97230                  0.189                 3.749  ...
# 97378                  0.174                 3.899  ...
# 97527                  0.175                 3.875  ...
# 97675                  0.172                 3.949  ...
# 97820                  0.178                 3.899  ...
# 97965                  0.181                 3.899  ...
# 98112                  0.180                 3.969  ...
# 98259                  0.176                 3.969  ...
# 98401                  0.180                 3.899  ...
# 98545                  0.190                 3.899  ...
# 98689                  0.209                 3.749  ...
# 98831                  0.195                 3.879  ...
# 98977                  0.216                 3.769  ...
# 99122                  0.213                 3.699  ...
# 99266                  0.212                 3.669  ...
# 99410                  0.201                 3.699  ...
# 99553                  0.201                 3.699  ...
# 99698                  0.201                 3.599  ...
#
#        PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 92319                     3.577                       0.104
# 92465                     3.590                       0.102
# 92610                     3.596                       0.102
# 92755                     3.596                       0.107
# 92901                     3.588                       0.102
# 93048                     3.570                       0.097
# 93192                     3.563                       0.097
# 93339                     3.570                       0.106
# 93487                     3.583                       0.110
# 93634                     3.593                       0.104
# 93778                     3.588                       0.108
# 93924                     3.624                       0.110
# 94070                     3.630                       0.113
# 94215                     3.629                       0.102
# 94361                     3.632                       0.102
# 94508                     3.625                       0.098
# 94656                     3.625                       0.103
# 94804                     3.656                       0.095
# 94951                     3.690                       0.107
# 95098                     3.793                       0.130
# 95211                     3.862                       0.087
# 95342                     3.873                       0.096
# 95486                     3.866                       0.090
# 95633                     3.849                       0.102
# 95779                     3.808                       0.107
# 95922                     3.804                       0.110
# 96069                     3.837                       0.119
# 96217                     3.863                       0.110
# 96362                     3.840                       0.108
# 96507                     3.808                       0.107
# 96651                     3.797                       0.109
# 96799                     3.766                       0.103
# 96943                     3.779                       0.105
# 97086                     3.840                       0.116
# 97230                     3.890                       0.128
# 97378                     3.992                       0.120
# 97527                     4.021                       0.120
# 97675                     4.055                       0.113
# 97820                     4.060                       0.116
# 97965                     4.085                       0.122
# 98112                     4.078                       0.125
# 98259                     4.074                       0.112
# 98401                     4.028                       0.122
# 98545                     3.913                       0.127
# 98689                     3.849                       0.144
# 98831                     3.747                       0.113
# 98977                     3.702                       0.119
# 99122                     3.622                       0.117
# 99266                     3.615                       0.119
# 99410                     3.639                       0.110
# 99553                     3.645                       0.107
# 99698                     3.610                       0.100
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 92319                     2.9900                     3.9510
# 92465                     2.9900                     3.9014
# 92610                     2.9900                     3.9014
# 92755                     2.9240                     3.9537
# 92901                     2.9900                     3.9537
# 93048                     2.9900                     3.8899
# 93192                     2.9900                     3.8910
# 93339                     2.9900                     3.9549
# 93487                     2.9900                     4.0687
# 93634                     2.9900                     4.2590
# 93778                     2.9900                     4.2590
# 93924                     3.3200                     3.9743
# 94070                     2.9900                     3.9682
# 94215                     2.9900                     3.9747
# 94361                     2.9900                     3.9312
# 94508                     3.0599                     4.0060
# 94656                     2.9900                     4.0060
# 94804                     3.2758                     3.8875
# 94951                     2.9900                     3.9461
# 95098                     2.9900                     4.1181
# 95211                     3.5800                     3.9500
# 95342                     3.3016                     4.4394
# 95486                     3.5200                     4.4394
# 95633                     3.5403                     4.1678
# 95779                     3.5403                     4.1786
# 95922                     3.5200                     4.1069
# 96069                     2.9900                     4.1993
# 96217                     3.5200                     4.2560
# 96362                     3.5400                     4.1596
# 96507                     3.4900                     4.0900
# 96651                     3.4900                     4.1010
# 96799                     3.5000                     4.0380
# 96943                     3.5050                     4.0871
# 97086                     3.5300                     4.1800
# 97230                     3.5150                     4.2094
# 97378                     3.5400                     4.3950
# 97527                     3.5400                     4.3313
# 97675                     3.6950                     4.5510
# 97820                     3.6950                     4.4800
# 97965                     3.7600                     4.3978
# 98112                     3.5990                     4.3900
# 98259                     3.6025                     4.4135
# 98401                     3.7300                     4.4135
# 98545                     3.5700                     4.4990
# 98689                     3.5000                     4.4990
# 98831                     3.4600                     4.2552
# 98977                     3.3500                     4.1213
# 99122                     3.3400                     4.0849
# 99266                     3.3400                     4.0849
# 99410                     3.3500                     3.9892
# 99553                     3.3500                     3.9892
# 99698                     3.3500                     3.9585
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO  coluna sem nocao  \
# 92319                          0.029    1  2018           DEFAULT
# 92465                          0.028    1  2018           DEFAULT
# 92610                          0.028    1  2018           DEFAULT
# 92755                          0.030    1  2018           DEFAULT
# 92901                          0.028    2  2018           DEFAULT
# 93048                          0.027    2  2018           DEFAULT
# 93192                          0.027    2  2018           DEFAULT
# 93339                          0.030    2  2018           DEFAULT
# 93487                          0.031    3  2018           DEFAULT
# 93634                          0.029    3  2018           DEFAULT
# 93778                          0.030    3  2018           DEFAULT
# 93924                          0.030    3  2018           DEFAULT
# 94070                          0.031    4  2018           DEFAULT
# 94215                          0.028    4  2018           DEFAULT
# 94361                          0.028    4  2018           DEFAULT
# 94508                          0.027    4  2018           DEFAULT
# 94656                          0.028    4  2018           DEFAULT
# 94804                          0.026    5  2018           DEFAULT
# 94951                          0.029    5  2018           DEFAULT
# 95098                          0.034    5  2018           DEFAULT
# 95211                          0.023    5  2018           DEFAULT
# 95342                          0.025    6  2018           DEFAULT
# 95486                          0.023    6  2018           DEFAULT
# 95633                          0.027    6  2018           DEFAULT
# 95779                          0.028    6  2018           DEFAULT
# 95922                          0.029    7  2018           DEFAULT
# 96069                          0.031    7  2018           DEFAULT
# 96217                          0.028    7  2018           DEFAULT
# 96362                          0.028    7  2018           DEFAULT
# 96507                          0.028    7  2018           DEFAULT
# 96651                          0.029    8  2018           DEFAULT
# 96799                          0.027    8  2018           DEFAULT
# 96943                          0.028    8  2018           DEFAULT
# 97086                          0.030    8  2018           DEFAULT
# 97230                          0.033    9  2018           DEFAULT
# 97378                          0.030    9  2018           DEFAULT
# 97527                          0.030    9  2018           DEFAULT
# 97675                          0.028    9  2018           DEFAULT
# 97820                          0.029    9  2018           DEFAULT
# 97965                          0.030   10  2018           DEFAULT
# 98112                          0.031   10  2018           DEFAULT
# 98259                          0.027   10  2018           DEFAULT
# 98401                          0.030   10  2018           DEFAULT
# 98545                          0.032   11  2018           DEFAULT
# 98689                          0.037   11  2018           DEFAULT
# 98831                          0.030   11  2018           DEFAULT
# 98977                          0.032   11  2018           DEFAULT
# 99122                          0.032   12  2018           DEFAULT
# 99266                          0.033   12  2018           DEFAULT
# 99410                          0.030   12  2018           DEFAULT
# 99553                          0.029   12  2018           DEFAULT
# 99698                          0.028   12  2018           DEFAULT
#
#        coluna a partir de lista  PREÇO MÉDIO REVENDA (dólares)
# 92319                     95351                         23.928
# 92465                     95502                         24.012
# 92610                     95654                         24.036
# 92755                     95806                         24.114
# 92901                     95958                         24.024
# 93048                     96109                         24.084
# 93192                     96259                         24.048
# 93339                     96411                         23.952
# 93487                     96563                         23.820
# 93634                     96715                         24.018
# 93778                     96866                         23.928
# 93924                     97017                         23.952
# 94070                     97168                         24.042
# 94215                     97319                         24.048
# 94361                     97471                         24.036
# 94508                     97622                         24.210
# 94656                     97773                         24.030
# 94804                     97924                         24.192
# 94951                     98074                         24.336
# 95098                     98225                         25.176
# 95211                     98371                         27.012
# 95342                     98517                         26.496
# 95486                     98670                         26.094
# 95633                     98821                         25.956
# 95779                     98972                         25.644
# 95922                     99122                         25.632
# 96069                     99271                         25.554
# 96217                     99422                         25.608
# 96362                     99573                         25.446
# 96507                     99725                         25.410
# 96651                     99876                         25.326
# 96799                    100027                         25.248
# 96943                    100177                         25.134
# 97086                    100326                         25.344
# 97230                    100477                         25.776
# 97378                    100628                         26.454
# 97527                    100780                         26.484
# 97675                    100930                         26.856
# 97820                    101079                         26.814
# 97965                    101228                         26.994
# 98112                    101378                         27.072
# 98259                    101529                         27.036
# 98401                    101679                         26.940
# 98545                    101828                         26.712
# 98689                    101977                         26.262
# 98831                    102127                         25.992
# 98977                    102276                         25.746
# 99122                    102426                         25.122
# 99266                    102575                         24.888
# 99410                    102724                         24.774
# 99553                    102874                         24.774
# 99698                    103025                         24.678
#
# [52 rows x 23 columns]

# %% [markdown]
# #### **Estatísticas Descritivas**

# %% [markdown]
# ### 7.3 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %% [markdown]
# <h2>8. Assuntos para continuar os estudos</h2>
# <hr/>
#
# - join
# - concat
# - plot
# - data cleaning
